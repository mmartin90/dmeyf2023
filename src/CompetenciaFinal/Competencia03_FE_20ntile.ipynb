# %%
# %%bash
# pip install --upgrade duckdb
# pip install --upgrade jupysql
# pip install --upgrade duckdb-engine

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %%
# %sql duckdb:///:default:

# %%
# %%sql
# create or replace table competencia_01 as
# select
#     *
# from read_csv_auto('~/buckets/b1/datasets/competencia_03_preFE.csv.gz')

# %%
# %%sql
# CREATE MACRO suma_sin_null(a, b) AS ifnull(a, 0) + ifnull(b, 0);

# %%
# %%sql
# CREATE MACRO calculo_ratio(a, b) AS NULLIF(a / NULLIF(b,0),0);

# %%
# %%sql
# CREATE MACRO corrijo_drift_rank(a,b) AS percent_rank() over (partition by b order by a);

# %% [markdown]
# Creando el texto con una función

# %%
campos_m = ['mrentabilidad', 'mrentabilidad_annual', 'mcomisiones', 'mactivos_margen', 
          'mpasivos_margen', 'mcuenta_corriente_adicional', 'mcuenta_corriente', 'mcaja_ahorro', 
          'mcaja_ahorro_adicional', 'mcaja_ahorro_dolares', 'mcuentas_saldo', 'mautoservicio', 
          'mtarjeta_visa_consumo', 'mtarjeta_master_consumo', 'mprestamos_personales', 'mprestamos_prendarios', 'mprestamos_hipotecarios', 
          'mplazo_fijo_dolares', 'mplazo_fijo_pesos', 'minversion1_pesos', 'minversion1_dolares', 'minversion2', 
          'mpayroll', 'mpayroll2', 'mcuenta_debitos_automaticos', 'mttarjeta_visa_debitos_automaticos','mttarjeta_master_debitos_automaticos', 
          'mpagodeservicios', 'mpagomiscuentas', 'mcajeros_propios_descuentos', 'mtarjeta_visa_descuentos', 
          'mtarjeta_master_descuentos', 'mcomisiones_mantenimiento', 'mcomisiones_otras', 
          'mforex_buy', 'mforex_sell', 'mtransferencias_recibidas', 'mtransferencias_emitidas', 
          'mextraccion_autoservicio', 'mcheques_depositados', 'mcheques_emitidos','mcheques_depositados_rechazados', 
          'mcheques_emitidos_rechazados', 'matm', 'matm_other', 'Master_mfinanciacion_limite', 
          'Master_msaldototal', 'Master_msaldopesos', 'Master_msaldodolares', 'Master_mconsumospesos', 'Master_mconsumosdolares', 
          'Master_mlimitecompra', 'Master_madelantopesos', 'Master_madelantodolares', 'Master_mpagado', 'Master_mpagospesos', 'Master_mpagosdolares', 
          'Master_mconsumototal', 'Master_mpagominimo', 'Visa_mfinanciacion_limite', 
          'Visa_msaldototal', 'Visa_msaldopesos', 'Visa_msaldodolares', 'Visa_mconsumospesos', 
          'Visa_mconsumosdolares', 'Visa_mlimitecompra', 'Visa_madelantopesos', 'Visa_madelantodolares', 'Visa_mpagado', 'Visa_mpagospesos', 
          'Visa_mpagosdolares', 'Visa_mconsumototal', 'Visa_mpagominimo']

# %%
nuevos_features = ""
for campo in campos_m:
  nuevos_features += f"\n, ntile(20) over (partition by foto_mes order by {campo} desc) as {campo}_sin_drif"
print(nuevos_features)
# Out:
# , ntile(20) over (partition by foto_mes order by mrentabilidad desc) as mrentabilidad_sin_drif
# , ntile(20) over (partition by foto_mes order by mrentabilidad_annual desc) as mrentabilidad_annual_sin_drif
# , ntile(20) over (partition by foto_mes order by mcomisiones desc) as mcomisiones_sin_drif
# , ntile(20) over (partition by foto_mes order by mactivos_margen desc) as mactivos_margen_sin_drif
# , ntile(20) over (partition by foto_mes order by mpasivos_margen desc) as mpasivos_margen_sin_drif
# , ntile(20) over (partition by foto_mes order by mcuenta_corriente_adicional desc) as mcuenta_corriente_adicional_sin_drif
# , ntile(20) over (partition by foto_mes order by mcuenta_corriente desc) as mcuenta_corriente_sin_drif
# , ntile(20) over (partition by foto_mes order by mcaja_ahorro desc) as mcaja_ahorro_sin_drif
# , ntile(20) over (partition by foto_mes order by mcaja_ahorro_adicional desc) as mcaja_ahorro_adicional_sin_drif
# ...

# %%
campos = ['active_quarter', 'cliente_vip', 'internet', 'cliente_edad', 'cliente_antiguedad', 'mrentabilidad_sin_drif', 'mrentabilidad_annual_sin_drif', 'mcomisiones_sin_drif', 'mactivos_margen_sin_drif', 
          'mpasivos_margen_sin_drif', 'cproductos', 'tcuentas', 'ccuenta_corriente', 'mcuenta_corriente_adicional_sin_drif', 'mcuenta_corriente_sin_drif', 'ccaja_ahorro', 'mcaja_ahorro_sin_drif', 
          'mcaja_ahorro_adicional_sin_drif', 'mcaja_ahorro_dolares_sin_drif', 'cdescubierto_preacordado', 'mcuentas_saldo_sin_drif', 'ctarjeta_debito', 'ctarjeta_debito_transacciones', 'mautoservicio_sin_drif', 
          'ctarjeta_visa', 'ctarjeta_visa_transacciones', 'mtarjeta_visa_consumo_sin_drif', 'ctarjeta_master', 'ctarjeta_master_transacciones', 'mtarjeta_master_consumo_sin_drif', 
          'cprestamos_personales', 'mprestamos_personales_sin_drif', 'cprestamos_prendarios', 'mprestamos_prendarios_sin_drif', 'cprestamos_hipotecarios', 'mprestamos_hipotecarios_sin_drif', 
          'cplazo_fijo', 'mplazo_fijo_dolares_sin_drif', 'mplazo_fijo_pesos_sin_drif', 'cinversion1', 'minversion1_pesos_sin_drif', 'minversion1_dolares_sin_drif', 'cinversion2', 'minversion2_sin_drif', 
          'cseguro_vida', 'cseguro_auto', 'cseguro_vivienda', 'cseguro_accidentes_personales', 'ccaja_seguridad', 'cpayroll_trx', 'mpayroll_sin_drif', 'mpayroll2_sin_drif', 'cpayroll2_trx', 
          'ccuenta_debitos_automaticos', 'mcuenta_debitos_automaticos_sin_drif', 'ctarjeta_visa_debitos_automaticos', 'mttarjeta_visa_debitos_automaticos_sin_drif', 
          'ctarjeta_master_debitos_automaticos', 'mttarjeta_master_debitos_automaticos_sin_drif', 'cpagodeservicios', 'mpagodeservicios_sin_drif', 'cpagomiscuentas', 'mpagomiscuentas_sin_drif', 
          'ccajeros_propios_descuentos', 'mcajeros_propios_descuentos_sin_drif', 'ctarjeta_visa_descuentos', 'mtarjeta_visa_descuentos_sin_drif', 'ctarjeta_master_descuentos', 
          'mtarjeta_master_descuentos_sin_drif', 'ccomisiones_mantenimiento', 'mcomisiones_mantenimiento_sin_drif', 'ccomisiones_otras', 'mcomisiones_otras_sin_drif', 'cforex', 'cforex_buy', 
          'mforex_buy_sin_drif', 'cforex_sell', 'mforex_sell_sin_drif', 'ctransferencias_recibidas', 'mtransferencias_recibidas_sin_drif', 'ctransferencias_emitidas', 'mtransferencias_emitidas_sin_drif', 
          'cextraccion_autoservicio', 'mextraccion_autoservicio_sin_drif', 'ccheques_depositados', 'mcheques_depositados_sin_drif', 'ccheques_emitidos', 'mcheques_emitidos_sin_drif', 
          'ccheques_depositados_rechazados', 'mcheques_depositados_rechazados_sin_drif', 'ccheques_emitidos_rechazados', 'mcheques_emitidos_rechazados_sin_drif', 'tcallcenter', 
          'ccallcenter_transacciones', 'thomebanking', 'chomebanking_transacciones', 'ccajas_transacciones', 'ccajas_consultas', 'ccajas_depositos', 'ccajas_extracciones', 
          'ccajas_otras', 'catm_trx', 'matm_sin_drif', 'catm_trx_other', 'matm_other_sin_drif', 'ctrx_quarter', 'Master_delinquency', 'Master_status', 'Master_mfinanciacion_limite_sin_drif', 
          'Master_Fvencimiento', 'Master_Finiciomora', 'Master_msaldototal_sin_drif', 'Master_msaldopesos_sin_drif', 'Master_msaldodolares_sin_drif', 'Master_mconsumospesos_sin_drif', 'Master_mconsumosdolares_sin_drif', 
          'Master_mlimitecompra_sin_drif', 'Master_madelantopesos_sin_drif', 'Master_madelantodolares_sin_drif', 'Master_fultimo_cierre', 'Master_mpagado_sin_drif', 'Master_mpagospesos_sin_drif', 'Master_mpagosdolares_sin_drif', 
          'Master_fechaalta', 'Master_mconsumototal_sin_drif', 'Master_cconsumos_sin_drif', 'Master_cadelantosefectivo', 'Master_mpagominimo_sin_drif', 'Visa_delinquency', 'Visa_status', 
          'Visa_mfinanciacion_limite_sin_drif', 'Visa_Fvencimiento', 'Visa_Finiciomora', 'Visa_msaldototal_sin_drif', 'Visa_msaldopesos_sin_drif', 'Visa_msaldodolares_sin_drif', 'Visa_mconsumospesos_sin_drif', 
          'Visa_mconsumosdolares_sin_drif', 'Visa_mlimitecompra_sin_drif', 'Visa_madelantopesos_sin_drif', 'Visa_madelantodolares_sin_drif', 'Visa_fultimo_cierre', 'Visa_mpagado_sin_drif', 'Visa_mpagospesos_sin_drif', 
          'Visa_mpagosdolares_sin_drif', 'Visa_fechaalta', 'Visa_mconsumototal_sin_drif', 'Visa_cconsumos', 'Visa_cadelantosefectivo', 'Visa_mpagominimo_sin_drif']

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, lag({campo}, 1) over (partition by numero_de_cliente order by foto_mes) as {campo}_lag_1"
print(nuevos_features)
# Out:
# , lag(active_quarter, 1) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_1
# , lag(cliente_vip, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_1
# , lag(internet, 1) over (partition by numero_de_cliente order by foto_mes) as internet_lag_1
# , lag(cliente_edad, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_1
# , lag(cliente_antiguedad, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_1
# , lag(mrentabilidad_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_1
# , lag(mrentabilidad_annual_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_1
# , lag(mcomisiones_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_1
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, lag({campo}, 3) over (partition by numero_de_cliente order by foto_mes) as {campo}_lag_3"
print(nuevos_features)
# Out:
# , lag(active_quarter, 3) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_3
# , lag(cliente_vip, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_3
# , lag(internet, 3) over (partition by numero_de_cliente order by foto_mes) as internet_lag_3
# , lag(cliente_edad, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_3
# , lag(cliente_antiguedad, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_3
# , lag(mrentabilidad_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_3
# , lag(mrentabilidad_annual_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_3
# , lag(mcomisiones_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_3
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, lag({campo}, 6) over (partition by numero_de_cliente order by foto_mes) as {campo}_lag_6"
print(nuevos_features)
# Out:
# , lag(active_quarter, 6) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_6
# , lag(cliente_vip, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_6
# , lag(internet, 6) over (partition by numero_de_cliente order by foto_mes) as internet_lag_6
# , lag(cliente_edad, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_6
# , lag(cliente_antiguedad, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_6
# , lag(mrentabilidad_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_6
# , lag(mrentabilidad_annual_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_6
# , lag(mcomisiones_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_6
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, avg({campo}) over ventana_6 as {campo}_avg"
print(nuevos_features)
# Out:
# , avg(active_quarter) over ventana_6 as active_quarter_avg
# , avg(cliente_vip) over ventana_6 as cliente_vip_avg
# , avg(internet) over ventana_6 as internet_avg
# , avg(cliente_edad) over ventana_6 as cliente_edad_avg
# , avg(cliente_antiguedad) over ventana_6 as cliente_antiguedad_avg
# , avg(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_avg
# , avg(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_avg
# , avg(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_avg
# , avg(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_avg
# , avg(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_avg
# , avg(cproductos) over ventana_6 as cproductos_avg
# , avg(tcuentas) over ventana_6 as tcuentas_avg
# , avg(ccuenta_corriente) over ventana_6 as ccuenta_corriente_avg
# , avg(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_avg
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, max({campo}) over ventana_6 as {campo}_max"
print(nuevos_features)
# Out:
# , max(active_quarter) over ventana_6 as active_quarter_max
# , max(cliente_vip) over ventana_6 as cliente_vip_max
# , max(internet) over ventana_6 as internet_max
# , max(cliente_edad) over ventana_6 as cliente_edad_max
# , max(cliente_antiguedad) over ventana_6 as cliente_antiguedad_max
# , max(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_max
# , max(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_max
# , max(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_max
# , max(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_max
# , max(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_max
# , max(cproductos) over ventana_6 as cproductos_max
# , max(tcuentas) over ventana_6 as tcuentas_max
# , max(ccuenta_corriente) over ventana_6 as ccuenta_corriente_max
# , max(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_max
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, min({campo}) over ventana_6 as {campo}_min"
print(nuevos_features)
# Out:
# , min(active_quarter) over ventana_6 as active_quarter_min
# , min(cliente_vip) over ventana_6 as cliente_vip_min
# , min(internet) over ventana_6 as internet_min
# , min(cliente_edad) over ventana_6 as cliente_edad_min
# , min(cliente_antiguedad) over ventana_6 as cliente_antiguedad_min
# , min(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_min
# , min(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_min
# , min(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_min
# , min(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_min
# , min(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_min
# , min(cproductos) over ventana_6 as cproductos_min
# , min(tcuentas) over ventana_6 as tcuentas_min
# , min(ccuenta_corriente) over ventana_6 as ccuenta_corriente_min
# , min(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_min
# ...

# %%
nuevos_features = ""
for campo in campos:
  nuevos_features += f"\n, regr_slope({campo}, cliente_antiguedad) over ventana_6 as {campo}_slope_6"
print(nuevos_features)
# Out:
# , regr_slope(active_quarter, cliente_antiguedad) over ventana_6 as active_quarter_slope_6
# , regr_slope(cliente_vip, cliente_antiguedad) over ventana_6 as cliente_vip_slope_6
# , regr_slope(internet, cliente_antiguedad) over ventana_6 as internet_slope_6
# , regr_slope(cliente_edad, cliente_antiguedad) over ventana_6 as cliente_edad_slope_6
# , regr_slope(cliente_antiguedad, cliente_antiguedad) over ventana_6 as cliente_antiguedad_slope_6
# , regr_slope(mrentabilidad_sin_drif, cliente_antiguedad) over ventana_6 as mrentabilidad_sin_drif_slope_6
# , regr_slope(mrentabilidad_annual_sin_drif, cliente_antiguedad) over ventana_6 as mrentabilidad_annual_sin_drif_slope_6
# , regr_slope(mcomisiones_sin_drif, cliente_antiguedad) over ventana_6 as mcomisiones_sin_drif_slope_6
# , regr_slope(mactivos_margen_sin_drif, cliente_antiguedad) over ventana_6 as mactivos_margen_sin_drif_slope_6
# ...

# %% [markdown]
# Elimino variables a las que se les quito drift.

# %%
nuevos_features = ""
for campo in campos_m:
  nuevos_features += f"\n ALTER TABLE table_3 DROP COLUMN {campo};"
print(nuevos_features)
# Out:
#  ALTER TABLE table_3 DROP COLUMN mrentabilidad;
#  ALTER TABLE table_3 DROP COLUMN mrentabilidad_annual;
#  ALTER TABLE table_3 DROP COLUMN mcomisiones;
#  ALTER TABLE table_3 DROP COLUMN mactivos_margen;
#  ALTER TABLE table_3 DROP COLUMN mpasivos_margen;
#  ALTER TABLE table_3 DROP COLUMN mcuenta_corriente_adicional;
#  ALTER TABLE table_3 DROP COLUMN mcuenta_corriente;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro_adicional;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro_dolares;
#  ALTER TABLE table_3 DROP COLUMN mcuentas_saldo;
#  ALTER TABLE table_3 DROP COLUMN mautoservicio;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_visa_consumo;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_master_consumo;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_personales;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_prendarios;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_hipotecarios;
#  ALTER TABLE table_3 DROP COLUMN mplazo_fijo_dolares;
# ...

# %% [markdown]
# #### Aplicando funciones para Competencia02

# %%
# %%sql
# CREATE TABLE table_1 AS
# SELECT
#     *,
#
#     suma_sin_null(ctarjeta_visa_transacciones, ctarjeta_master_transacciones) as tc_transacciones_total,
#     suma_sin_null(ctarjeta_visa, ctarjeta_master) as tc_ctarjeta_total,
#     suma_sin_null(mtarjeta_visa_consumo, mtarjeta_master_consumo) as tc_consumo_total,
#     suma_sin_null(Master_mconsumototal, Visa_mconsumototal) as tc_mconsumo_total,
#     suma_sin_null(Visa_mlimitecompra, Master_mlimitecompra) as tc_limcompra_total,
#     suma_sin_null(Master_mpagado, Visa_mpagado) as tc_pagado_total,
#     suma_sin_null(Master_mpagominimo, Visa_mpagominimo) as tc_saldo_total,
#     suma_sin_null(Master_msaldototal, Visa_msaldototal) as tc_pagomin_total, ifnull(mprestamos_personales, 0) + ifnull(mprestamos_prendarios, 0) +
#         ifnull(mprestamos_hipotecarios, 0) as pasivos_total,  ifnull(mplazo_fijo_dolares, 0) + ifnull(mplazo_fijo_pesos, 0) + ifnull(minversion1_pesos, 0) +
#         ifnull(minversion1_dolares, 0) + ifnull(minversion2, 0) as activos_total,
#     ifnull(mpayroll, 0) + ifnull(mpayroll2, 0) as flujos_ingresos_total,  ifnull(mcajeros_propios_descuentos, 0) + ifnull(mtarjeta_visa_descuentos, 0) +
#         ifnull(mtarjeta_master_descuentos, 0) as beneficios_total,
#     ifnull(mcomisiones_mantenimiento, 0) + ifnull(mcomisiones_otras, 0) as comisiones_total,
#     ifnull(mcuenta_debitos_automaticos, 0) + ifnull(mttarjeta_visa_debitos_automaticos, 0) + ifnull(mttarjeta_master_debitos_automaticos, 0) +
#         ifnull(mpagodeservicios, 0) + ifnull(mpagomiscuentas, 0) as gastos_total,
#
#
#     calculo_ratio(tc_consumo_total, flujos_ingresos_total) as consumo_sobre_ingresos,
#     calculo_ratio(tc_mconsumo_total, flujos_ingresos_total) as tcm_consumo_sobre_ingresos,
#     calculo_ratio(tc_pagado_total, flujos_ingresos_total) as pagado_sobre_ingresos,
#     calculo_ratio(tc_pagado_total, activos_total) as pagado_sobre_activos,
#     calculo_ratio(tc_pagomin_total, flujos_ingresos_total) as pagomin_sobre_ingresos,
#     calculo_ratio(tc_consumo_total, activos_total) as gastos_sobre_activos,
#     calculo_ratio(activos_total, pasivos_total) as activos_sobre_pasivos,
#     calculo_ratio(beneficios_total, comisiones_total) as beneficios_sobre_comisiones,
#     calculo_ratio(beneficios_total, tc_consumo_total) as beneficios_sobre_consumos,
#     calculo_ratio(gastos_total, flujos_ingresos_total) as gastos_sobre_ingresos,
#     calculo_ratio(tc_limcompra_total, tc_consumo_total) as lim_sobre_consumos,
#
#
#     corrijo_drift_rank(tc_mconsumo_total, foto_mes) as tc_mconsumo_total,
#     corrijo_drift_rank(tc_limcompra_total, foto_mes) as tc_limcompra_total,
#     corrijo_drift_rank(tc_pagado_total, foto_mes) as tc_pagado_total,
#     corrijo_drift_rank(pasivos_total, foto_mes) as pasivos_total,
#     corrijo_drift_rank(activos_total, foto_mes) as activos_total,
#     corrijo_drift_rank(flujos_ingresos_total, foto_mes) as flujos_ingresos_total,
#     corrijo_drift_rank(comisiones_total, foto_mes) as comisiones_total,
#     corrijo_drift_rank(gastos_total, foto_mes) as gastos_total
#
#
# FROM competencia_01

# %%
# %%sql
# DROP TABLE IF EXISTS competencia_01

# %%
# %%sql
# CREATE TABLE table_2 AS
# SELECT
#     *
#
#     , ntile(20) over (partition by foto_mes order by mrentabilidad desc) as mrentabilidad_sin_drif
#     , ntile(20) over (partition by foto_mes order by mrentabilidad_annual desc) as mrentabilidad_annual_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcomisiones desc) as mcomisiones_sin_drif
#     , ntile(20) over (partition by foto_mes order by mactivos_margen desc) as mactivos_margen_sin_drif
#     , ntile(20) over (partition by foto_mes order by mpasivos_margen desc) as mpasivos_margen_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcuenta_corriente_adicional desc) as mcuenta_corriente_adicional_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcuenta_corriente desc) as mcuenta_corriente_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcaja_ahorro desc) as mcaja_ahorro_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcaja_ahorro_adicional desc) as mcaja_ahorro_adicional_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcaja_ahorro_dolares desc) as mcaja_ahorro_dolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcuentas_saldo desc) as mcuentas_saldo_sin_drif
#     , ntile(20) over (partition by foto_mes order by mautoservicio desc) as mautoservicio_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtarjeta_visa_consumo desc) as mtarjeta_visa_consumo_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtarjeta_master_consumo desc) as mtarjeta_master_consumo_sin_drif
#     , ntile(20) over (partition by foto_mes order by mprestamos_personales desc) as mprestamos_personales_sin_drif
#     , ntile(20) over (partition by foto_mes order by mprestamos_prendarios desc) as mprestamos_prendarios_sin_drif
#     , ntile(20) over (partition by foto_mes order by mprestamos_hipotecarios desc) as mprestamos_hipotecarios_sin_drif
#     , ntile(20) over (partition by foto_mes order by mplazo_fijo_dolares desc) as mplazo_fijo_dolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by mplazo_fijo_pesos desc) as mplazo_fijo_pesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by minversion1_pesos desc) as minversion1_pesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by minversion1_dolares desc) as minversion1_dolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by minversion2 desc) as minversion2_sin_drif
#     , ntile(20) over (partition by foto_mes order by mpayroll desc) as mpayroll_sin_drif
#     , ntile(20) over (partition by foto_mes order by mpayroll2 desc) as mpayroll2_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcuenta_debitos_automaticos desc) as mcuenta_debitos_automaticos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mttarjeta_visa_debitos_automaticos desc) as mttarjeta_visa_debitos_automaticos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mttarjeta_master_debitos_automaticos desc) as mttarjeta_master_debitos_automaticos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mpagodeservicios desc) as mpagodeservicios_sin_drif
#     , ntile(20) over (partition by foto_mes order by mpagomiscuentas desc) as mpagomiscuentas_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcajeros_propios_descuentos desc) as mcajeros_propios_descuentos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtarjeta_visa_descuentos desc) as mtarjeta_visa_descuentos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtarjeta_master_descuentos desc) as mtarjeta_master_descuentos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcomisiones_mantenimiento desc) as mcomisiones_mantenimiento_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcomisiones_otras desc) as mcomisiones_otras_sin_drif
#     , ntile(20) over (partition by foto_mes order by mforex_buy desc) as mforex_buy_sin_drif
#     , ntile(20) over (partition by foto_mes order by mforex_sell desc) as mforex_sell_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtransferencias_recibidas desc) as mtransferencias_recibidas_sin_drif
#     , ntile(20) over (partition by foto_mes order by mtransferencias_emitidas desc) as mtransferencias_emitidas_sin_drif
#     , ntile(20) over (partition by foto_mes order by mextraccion_autoservicio desc) as mextraccion_autoservicio_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcheques_depositados desc) as mcheques_depositados_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcheques_emitidos desc) as mcheques_emitidos_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcheques_depositados_rechazados desc) as mcheques_depositados_rechazados_sin_drif
#     , ntile(20) over (partition by foto_mes order by mcheques_emitidos_rechazados desc) as mcheques_emitidos_rechazados_sin_drif
#     , ntile(20) over (partition by foto_mes order by matm desc) as matm_sin_drif
#     , ntile(20) over (partition by foto_mes order by matm_other desc) as matm_other_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mfinanciacion_limite desc) as Master_mfinanciacion_limite_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_msaldototal desc) as Master_msaldototal_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_msaldopesos desc) as Master_msaldopesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_msaldodolares desc) as Master_msaldodolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mconsumospesos desc) as Master_mconsumospesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mconsumosdolares desc) as Master_mconsumosdolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mlimitecompra desc) as Master_mlimitecompra_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_madelantopesos desc) as Master_madelantopesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_madelantodolares desc) as Master_madelantodolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mpagado desc) as Master_mpagado_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mpagospesos desc) as Master_mpagospesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mpagosdolares desc) as Master_mpagosdolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mconsumototal desc) as Master_mconsumototal_sin_drif
#     , ntile(20) over (partition by foto_mes order by Master_mpagominimo desc) as Master_mpagominimo_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mfinanciacion_limite desc) as Visa_mfinanciacion_limite_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_msaldototal desc) as Visa_msaldototal_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_msaldopesos desc) as Visa_msaldopesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_msaldodolares desc) as Visa_msaldodolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mconsumospesos desc) as Visa_mconsumospesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mconsumosdolares desc) as Visa_mconsumosdolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mlimitecompra desc) as Visa_mlimitecompra_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_madelantopesos desc) as Visa_madelantopesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_madelantodolares desc) as Visa_madelantodolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mpagado desc) as Visa_mpagado_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mpagospesos desc) as Visa_mpagospesos_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mpagosdolares desc) as Visa_mpagosdolares_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mconsumototal desc) as Visa_mconsumototal_sin_drif
#     , ntile(20) over (partition by foto_mes order by Visa_mpagominimo desc) as Visa_mpagominimo_sin_drif
#
# FROM table_1

# %%
# %%sql
# DROP TABLE IF EXISTS table_1

# %%
# %%sql
# CREATE TABLE table_3 AS
# SELECT
#     *
#
#     , lag(active_quarter, 1) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_1
#     , lag(cliente_vip, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_1
#     , lag(internet, 1) over (partition by numero_de_cliente order by foto_mes) as internet_lag_1
#     , lag(cliente_edad, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_1
#     , lag(cliente_antiguedad, 1) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_1
#     , lag(mrentabilidad_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_1
#     , lag(mrentabilidad_annual_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_1
#     , lag(mcomisiones_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_1
#     , lag(mactivos_margen_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mactivos_margen_sin_drif_lag_1
#     , lag(mpasivos_margen_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mpasivos_margen_sin_drif_lag_1
#     , lag(cproductos, 1) over (partition by numero_de_cliente order by foto_mes) as cproductos_lag_1
#     , lag(tcuentas, 1) over (partition by numero_de_cliente order by foto_mes) as tcuentas_lag_1
#     , lag(ccuenta_corriente, 1) over (partition by numero_de_cliente order by foto_mes) as ccuenta_corriente_lag_1
#     , lag(mcuenta_corriente_adicional_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_adicional_sin_drif_lag_1
#     , lag(mcuenta_corriente_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_sin_drif_lag_1
#     , lag(ccaja_ahorro, 1) over (partition by numero_de_cliente order by foto_mes) as ccaja_ahorro_lag_1
#     , lag(mcaja_ahorro_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_sin_drif_lag_1
#     , lag(mcaja_ahorro_adicional_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_adicional_sin_drif_lag_1
#     , lag(mcaja_ahorro_dolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_dolares_sin_drif_lag_1
#     , lag(cdescubierto_preacordado, 1) over (partition by numero_de_cliente order by foto_mes) as cdescubierto_preacordado_lag_1
#     , lag(mcuentas_saldo_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcuentas_saldo_sin_drif_lag_1
#     , lag(ctarjeta_debito, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_lag_1
#     , lag(ctarjeta_debito_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_transacciones_lag_1
#     , lag(mautoservicio_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mautoservicio_sin_drif_lag_1
#     , lag(ctarjeta_visa, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_lag_1
#     , lag(ctarjeta_visa_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_transacciones_lag_1
#     , lag(mtarjeta_visa_consumo_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_consumo_sin_drif_lag_1
#     , lag(ctarjeta_master, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_lag_1
#     , lag(ctarjeta_master_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_transacciones_lag_1
#     , lag(mtarjeta_master_consumo_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_consumo_sin_drif_lag_1
#     , lag(cprestamos_personales, 1) over (partition by numero_de_cliente order by foto_mes) as cprestamos_personales_lag_1
#     , lag(mprestamos_personales_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mprestamos_personales_sin_drif_lag_1
#     , lag(cprestamos_prendarios, 1) over (partition by numero_de_cliente order by foto_mes) as cprestamos_prendarios_lag_1
#     , lag(mprestamos_prendarios_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mprestamos_prendarios_sin_drif_lag_1
#     , lag(cprestamos_hipotecarios, 1) over (partition by numero_de_cliente order by foto_mes) as cprestamos_hipotecarios_lag_1
#     , lag(mprestamos_hipotecarios_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mprestamos_hipotecarios_sin_drif_lag_1
#     , lag(cplazo_fijo, 1) over (partition by numero_de_cliente order by foto_mes) as cplazo_fijo_lag_1
#     , lag(mplazo_fijo_dolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_dolares_sin_drif_lag_1
#     , lag(mplazo_fijo_pesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_pesos_sin_drif_lag_1
#     , lag(cinversion1, 1) over (partition by numero_de_cliente order by foto_mes) as cinversion1_lag_1
#     , lag(minversion1_pesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as minversion1_pesos_sin_drif_lag_1
#     , lag(minversion1_dolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as minversion1_dolares_sin_drif_lag_1
#     , lag(cinversion2, 1) over (partition by numero_de_cliente order by foto_mes) as cinversion2_lag_1
#     , lag(minversion2_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as minversion2_sin_drif_lag_1
#     , lag(cseguro_vida, 1) over (partition by numero_de_cliente order by foto_mes) as cseguro_vida_lag_1
#     , lag(cseguro_auto, 1) over (partition by numero_de_cliente order by foto_mes) as cseguro_auto_lag_1
#     , lag(cseguro_vivienda, 1) over (partition by numero_de_cliente order by foto_mes) as cseguro_vivienda_lag_1
#     , lag(cseguro_accidentes_personales, 1) over (partition by numero_de_cliente order by foto_mes) as cseguro_accidentes_personales_lag_1
#     , lag(ccaja_seguridad, 1) over (partition by numero_de_cliente order by foto_mes) as ccaja_seguridad_lag_1
#     , lag(cpayroll_trx, 1) over (partition by numero_de_cliente order by foto_mes) as cpayroll_trx_lag_1
#     , lag(mpayroll_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mpayroll_sin_drif_lag_1
#     , lag(mpayroll2_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mpayroll2_sin_drif_lag_1
#     , lag(cpayroll2_trx, 1) over (partition by numero_de_cliente order by foto_mes) as cpayroll2_trx_lag_1
#     , lag(ccuenta_debitos_automaticos, 1) over (partition by numero_de_cliente order by foto_mes) as ccuenta_debitos_automaticos_lag_1
#     , lag(mcuenta_debitos_automaticos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcuenta_debitos_automaticos_sin_drif_lag_1
#     , lag(ctarjeta_visa_debitos_automaticos, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_debitos_automaticos_lag_1
#     , lag(mttarjeta_visa_debitos_automaticos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_visa_debitos_automaticos_sin_drif_lag_1
#     , lag(ctarjeta_master_debitos_automaticos, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_debitos_automaticos_lag_1
#     , lag(mttarjeta_master_debitos_automaticos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_master_debitos_automaticos_sin_drif_lag_1
#     , lag(cpagodeservicios, 1) over (partition by numero_de_cliente order by foto_mes) as cpagodeservicios_lag_1
#     , lag(mpagodeservicios_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mpagodeservicios_sin_drif_lag_1
#     , lag(cpagomiscuentas, 1) over (partition by numero_de_cliente order by foto_mes) as cpagomiscuentas_lag_1
#     , lag(mpagomiscuentas_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mpagomiscuentas_sin_drif_lag_1
#     , lag(ccajeros_propios_descuentos, 1) over (partition by numero_de_cliente order by foto_mes) as ccajeros_propios_descuentos_lag_1
#     , lag(mcajeros_propios_descuentos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcajeros_propios_descuentos_sin_drif_lag_1
#     , lag(ctarjeta_visa_descuentos, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_descuentos_lag_1
#     , lag(mtarjeta_visa_descuentos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_descuentos_sin_drif_lag_1
#     , lag(ctarjeta_master_descuentos, 1) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_descuentos_lag_1
#     , lag(mtarjeta_master_descuentos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_descuentos_sin_drif_lag_1
#     , lag(ccomisiones_mantenimiento, 1) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_mantenimiento_lag_1
#     , lag(mcomisiones_mantenimiento_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_mantenimiento_sin_drif_lag_1
#     , lag(ccomisiones_otras, 1) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_otras_lag_1
#     , lag(mcomisiones_otras_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_otras_sin_drif_lag_1
#     , lag(cforex, 1) over (partition by numero_de_cliente order by foto_mes) as cforex_lag_1
#     , lag(cforex_buy, 1) over (partition by numero_de_cliente order by foto_mes) as cforex_buy_lag_1
#     , lag(mforex_buy_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mforex_buy_sin_drif_lag_1
#     , lag(cforex_sell, 1) over (partition by numero_de_cliente order by foto_mes) as cforex_sell_lag_1
#     , lag(mforex_sell_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mforex_sell_sin_drif_lag_1
#     , lag(ctransferencias_recibidas, 1) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_recibidas_lag_1
#     , lag(mtransferencias_recibidas_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_recibidas_sin_drif_lag_1
#     , lag(ctransferencias_emitidas, 1) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_emitidas_lag_1
#     , lag(mtransferencias_emitidas_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_emitidas_sin_drif_lag_1
#     , lag(cextraccion_autoservicio, 1) over (partition by numero_de_cliente order by foto_mes) as cextraccion_autoservicio_lag_1
#     , lag(mextraccion_autoservicio_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mextraccion_autoservicio_sin_drif_lag_1
#     , lag(ccheques_depositados, 1) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_lag_1
#     , lag(mcheques_depositados_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_sin_drif_lag_1
#     , lag(ccheques_emitidos, 1) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_lag_1
#     , lag(mcheques_emitidos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_sin_drif_lag_1
#     , lag(ccheques_depositados_rechazados, 1) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_rechazados_lag_1
#     , lag(mcheques_depositados_rechazados_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_rechazados_sin_drif_lag_1
#     , lag(ccheques_emitidos_rechazados, 1) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_rechazados_lag_1
#     , lag(mcheques_emitidos_rechazados_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_rechazados_sin_drif_lag_1
#     , lag(tcallcenter, 1) over (partition by numero_de_cliente order by foto_mes) as tcallcenter_lag_1
#     , lag(ccallcenter_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as ccallcenter_transacciones_lag_1
#     , lag(thomebanking, 1) over (partition by numero_de_cliente order by foto_mes) as thomebanking_lag_1
#     , lag(chomebanking_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as chomebanking_transacciones_lag_1
#     , lag(ccajas_transacciones, 1) over (partition by numero_de_cliente order by foto_mes) as ccajas_transacciones_lag_1
#     , lag(ccajas_consultas, 1) over (partition by numero_de_cliente order by foto_mes) as ccajas_consultas_lag_1
#     , lag(ccajas_depositos, 1) over (partition by numero_de_cliente order by foto_mes) as ccajas_depositos_lag_1
#     , lag(ccajas_extracciones, 1) over (partition by numero_de_cliente order by foto_mes) as ccajas_extracciones_lag_1
#     , lag(ccajas_otras, 1) over (partition by numero_de_cliente order by foto_mes) as ccajas_otras_lag_1
#     , lag(catm_trx, 1) over (partition by numero_de_cliente order by foto_mes) as catm_trx_lag_1
#     , lag(matm_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as matm_sin_drif_lag_1
#     , lag(catm_trx_other, 1) over (partition by numero_de_cliente order by foto_mes) as catm_trx_other_lag_1
#     , lag(matm_other_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as matm_other_sin_drif_lag_1
#     , lag(ctrx_quarter, 1) over (partition by numero_de_cliente order by foto_mes) as ctrx_quarter_lag_1
#     , lag(Master_delinquency, 1) over (partition by numero_de_cliente order by foto_mes) as Master_delinquency_lag_1
#     , lag(Master_status, 1) over (partition by numero_de_cliente order by foto_mes) as Master_status_lag_1
#     , lag(Master_mfinanciacion_limite_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mfinanciacion_limite_sin_drif_lag_1
#     , lag(Master_Fvencimiento, 1) over (partition by numero_de_cliente order by foto_mes) as Master_Fvencimiento_lag_1
#     , lag(Master_Finiciomora, 1) over (partition by numero_de_cliente order by foto_mes) as Master_Finiciomora_lag_1
#     , lag(Master_msaldototal_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_msaldototal_sin_drif_lag_1
#     , lag(Master_msaldopesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_msaldopesos_sin_drif_lag_1
#     , lag(Master_msaldodolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_msaldodolares_sin_drif_lag_1
#     , lag(Master_mconsumospesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumospesos_sin_drif_lag_1
#     , lag(Master_mconsumosdolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumosdolares_sin_drif_lag_1
#     , lag(Master_mlimitecompra_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mlimitecompra_sin_drif_lag_1
#     , lag(Master_madelantopesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_madelantopesos_sin_drif_lag_1
#     , lag(Master_madelantodolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_madelantodolares_sin_drif_lag_1
#     , lag(Master_fultimo_cierre, 1) over (partition by numero_de_cliente order by foto_mes) as Master_fultimo_cierre_lag_1
#     , lag(Master_mpagado_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mpagado_sin_drif_lag_1
#     , lag(Master_mpagospesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mpagospesos_sin_drif_lag_1
#     , lag(Master_mpagosdolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mpagosdolares_sin_drif_lag_1
#     , lag(Master_fechaalta, 1) over (partition by numero_de_cliente order by foto_mes) as Master_fechaalta_lag_1
#     , lag(Master_mconsumototal_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumototal_sin_drif_lag_1
#     , lag(Master_cconsumos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_cconsumos_sin_drif_lag_1
#     , lag(Master_cadelantosefectivo, 1) over (partition by numero_de_cliente order by foto_mes) as Master_cadelantosefectivo_lag_1
#     , lag(Master_mpagominimo_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Master_mpagominimo_sin_drif_lag_1
#     , lag(Visa_delinquency, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_delinquency_lag_1
#     , lag(Visa_status, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_status_lag_1
#     , lag(Visa_mfinanciacion_limite_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mfinanciacion_limite_sin_drif_lag_1
#     , lag(Visa_Fvencimiento, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_Fvencimiento_lag_1
#     , lag(Visa_Finiciomora, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_Finiciomora_lag_1
#     , lag(Visa_msaldototal_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldototal_sin_drif_lag_1
#     , lag(Visa_msaldopesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldopesos_sin_drif_lag_1
#     , lag(Visa_msaldodolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldodolares_sin_drif_lag_1
#     , lag(Visa_mconsumospesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumospesos_sin_drif_lag_1
#     , lag(Visa_mconsumosdolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumosdolares_sin_drif_lag_1
#     , lag(Visa_mlimitecompra_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mlimitecompra_sin_drif_lag_1
#     , lag(Visa_madelantopesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantopesos_sin_drif_lag_1
#     , lag(Visa_madelantodolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantodolares_sin_drif_lag_1
#     , lag(Visa_fultimo_cierre, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_fultimo_cierre_lag_1
#     , lag(Visa_mpagado_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagado_sin_drif_lag_1
#     , lag(Visa_mpagospesos_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagospesos_sin_drif_lag_1
#     , lag(Visa_mpagosdolares_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagosdolares_sin_drif_lag_1
#     , lag(Visa_fechaalta, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_fechaalta_lag_1
#     , lag(Visa_mconsumototal_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumototal_sin_drif_lag_1
#     , lag(Visa_cconsumos, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_cconsumos_lag_1
#     , lag(Visa_cadelantosefectivo, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_cadelantosefectivo_lag_1
#     , lag(Visa_mpagominimo_sin_drif, 1) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagominimo_sin_drif_lag_1
#
#
#     , lag(active_quarter, 3) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_3
#     , lag(cliente_vip, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_3
#     , lag(internet, 3) over (partition by numero_de_cliente order by foto_mes) as internet_lag_3
#     , lag(cliente_edad, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_3
#     , lag(cliente_antiguedad, 3) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_3
#     , lag(mrentabilidad_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_3
#     , lag(mrentabilidad_annual_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_3
#     , lag(mcomisiones_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_3
#     , lag(mactivos_margen_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mactivos_margen_sin_drif_lag_3
#     , lag(mpasivos_margen_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mpasivos_margen_sin_drif_lag_3
#     , lag(cproductos, 3) over (partition by numero_de_cliente order by foto_mes) as cproductos_lag_3
#     , lag(tcuentas, 3) over (partition by numero_de_cliente order by foto_mes) as tcuentas_lag_3
#     , lag(ccuenta_corriente, 3) over (partition by numero_de_cliente order by foto_mes) as ccuenta_corriente_lag_3
#     , lag(mcuenta_corriente_adicional_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_adicional_sin_drif_lag_3
#     , lag(mcuenta_corriente_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_sin_drif_lag_3
#     , lag(ccaja_ahorro, 3) over (partition by numero_de_cliente order by foto_mes) as ccaja_ahorro_lag_3
#     , lag(mcaja_ahorro_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_sin_drif_lag_3
#     , lag(mcaja_ahorro_adicional_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_adicional_sin_drif_lag_3
#     , lag(mcaja_ahorro_dolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_dolares_sin_drif_lag_3
#     , lag(cdescubierto_preacordado, 3) over (partition by numero_de_cliente order by foto_mes) as cdescubierto_preacordado_lag_3
#     , lag(mcuentas_saldo_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcuentas_saldo_sin_drif_lag_3
#     , lag(ctarjeta_debito, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_lag_3
#     , lag(ctarjeta_debito_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_transacciones_lag_3
#     , lag(mautoservicio_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mautoservicio_sin_drif_lag_3
#     , lag(ctarjeta_visa, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_lag_3
#     , lag(ctarjeta_visa_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_transacciones_lag_3
#     , lag(mtarjeta_visa_consumo_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_consumo_sin_drif_lag_3
#     , lag(ctarjeta_master, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_lag_3
#     , lag(ctarjeta_master_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_transacciones_lag_3
#     , lag(mtarjeta_master_consumo_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_consumo_sin_drif_lag_3
#     , lag(cprestamos_personales, 3) over (partition by numero_de_cliente order by foto_mes) as cprestamos_personales_lag_3
#     , lag(mprestamos_personales_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mprestamos_personales_sin_drif_lag_3
#     , lag(cprestamos_prendarios, 3) over (partition by numero_de_cliente order by foto_mes) as cprestamos_prendarios_lag_3
#     , lag(mprestamos_prendarios_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mprestamos_prendarios_sin_drif_lag_3
#     , lag(cprestamos_hipotecarios, 3) over (partition by numero_de_cliente order by foto_mes) as cprestamos_hipotecarios_lag_3
#     , lag(mprestamos_hipotecarios_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mprestamos_hipotecarios_sin_drif_lag_3
#     , lag(cplazo_fijo, 3) over (partition by numero_de_cliente order by foto_mes) as cplazo_fijo_lag_3
#     , lag(mplazo_fijo_dolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_dolares_sin_drif_lag_3
#     , lag(mplazo_fijo_pesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_pesos_sin_drif_lag_3
#     , lag(cinversion1, 3) over (partition by numero_de_cliente order by foto_mes) as cinversion1_lag_3
#     , lag(minversion1_pesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as minversion1_pesos_sin_drif_lag_3
#     , lag(minversion1_dolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as minversion1_dolares_sin_drif_lag_3
#     , lag(cinversion2, 3) over (partition by numero_de_cliente order by foto_mes) as cinversion2_lag_3
#     , lag(minversion2_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as minversion2_sin_drif_lag_3
#     , lag(cseguro_vida, 3) over (partition by numero_de_cliente order by foto_mes) as cseguro_vida_lag_3
#     , lag(cseguro_auto, 3) over (partition by numero_de_cliente order by foto_mes) as cseguro_auto_lag_3
#     , lag(cseguro_vivienda, 3) over (partition by numero_de_cliente order by foto_mes) as cseguro_vivienda_lag_3
#     , lag(cseguro_accidentes_personales, 3) over (partition by numero_de_cliente order by foto_mes) as cseguro_accidentes_personales_lag_3
#     , lag(ccaja_seguridad, 3) over (partition by numero_de_cliente order by foto_mes) as ccaja_seguridad_lag_3
#     , lag(cpayroll_trx, 3) over (partition by numero_de_cliente order by foto_mes) as cpayroll_trx_lag_3
#     , lag(mpayroll_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mpayroll_sin_drif_lag_3
#     , lag(mpayroll2_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mpayroll2_sin_drif_lag_3
#     , lag(cpayroll2_trx, 3) over (partition by numero_de_cliente order by foto_mes) as cpayroll2_trx_lag_3
#     , lag(ccuenta_debitos_automaticos, 3) over (partition by numero_de_cliente order by foto_mes) as ccuenta_debitos_automaticos_lag_3
#     , lag(mcuenta_debitos_automaticos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcuenta_debitos_automaticos_sin_drif_lag_3
#     , lag(ctarjeta_visa_debitos_automaticos, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_debitos_automaticos_lag_3
#     , lag(mttarjeta_visa_debitos_automaticos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_visa_debitos_automaticos_sin_drif_lag_3
#     , lag(ctarjeta_master_debitos_automaticos, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_debitos_automaticos_lag_3
#     , lag(mttarjeta_master_debitos_automaticos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_master_debitos_automaticos_sin_drif_lag_3
#     , lag(cpagodeservicios, 3) over (partition by numero_de_cliente order by foto_mes) as cpagodeservicios_lag_3
#     , lag(mpagodeservicios_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mpagodeservicios_sin_drif_lag_3
#     , lag(cpagomiscuentas, 3) over (partition by numero_de_cliente order by foto_mes) as cpagomiscuentas_lag_3
#     , lag(mpagomiscuentas_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mpagomiscuentas_sin_drif_lag_3
#     , lag(ccajeros_propios_descuentos, 3) over (partition by numero_de_cliente order by foto_mes) as ccajeros_propios_descuentos_lag_3
#     , lag(mcajeros_propios_descuentos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcajeros_propios_descuentos_sin_drif_lag_3
#     , lag(ctarjeta_visa_descuentos, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_descuentos_lag_3
#     , lag(mtarjeta_visa_descuentos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_descuentos_sin_drif_lag_3
#     , lag(ctarjeta_master_descuentos, 3) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_descuentos_lag_3
#     , lag(mtarjeta_master_descuentos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_descuentos_sin_drif_lag_3
#     , lag(ccomisiones_mantenimiento, 3) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_mantenimiento_lag_3
#     , lag(mcomisiones_mantenimiento_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_mantenimiento_sin_drif_lag_3
#     , lag(ccomisiones_otras, 3) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_otras_lag_3
#     , lag(mcomisiones_otras_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_otras_sin_drif_lag_3
#     , lag(cforex, 3) over (partition by numero_de_cliente order by foto_mes) as cforex_lag_3
#     , lag(cforex_buy, 3) over (partition by numero_de_cliente order by foto_mes) as cforex_buy_lag_3
#     , lag(mforex_buy_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mforex_buy_sin_drif_lag_3
#     , lag(cforex_sell, 3) over (partition by numero_de_cliente order by foto_mes) as cforex_sell_lag_3
#     , lag(mforex_sell_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mforex_sell_sin_drif_lag_3
#     , lag(ctransferencias_recibidas, 3) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_recibidas_lag_3
#     , lag(mtransferencias_recibidas_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_recibidas_sin_drif_lag_3
#     , lag(ctransferencias_emitidas, 3) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_emitidas_lag_3
#     , lag(mtransferencias_emitidas_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_emitidas_sin_drif_lag_3
#     , lag(cextraccion_autoservicio, 3) over (partition by numero_de_cliente order by foto_mes) as cextraccion_autoservicio_lag_3
#     , lag(mextraccion_autoservicio_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mextraccion_autoservicio_sin_drif_lag_3
#     , lag(ccheques_depositados, 3) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_lag_3
#     , lag(mcheques_depositados_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_sin_drif_lag_3
#     , lag(ccheques_emitidos, 3) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_lag_3
#     , lag(mcheques_emitidos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_sin_drif_lag_3
#     , lag(ccheques_depositados_rechazados, 3) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_rechazados_lag_3
#     , lag(mcheques_depositados_rechazados_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_rechazados_sin_drif_lag_3
#     , lag(ccheques_emitidos_rechazados, 3) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_rechazados_lag_3
#     , lag(mcheques_emitidos_rechazados_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_rechazados_sin_drif_lag_3
#     , lag(tcallcenter, 3) over (partition by numero_de_cliente order by foto_mes) as tcallcenter_lag_3
#     , lag(ccallcenter_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as ccallcenter_transacciones_lag_3
#     , lag(thomebanking, 3) over (partition by numero_de_cliente order by foto_mes) as thomebanking_lag_3
#     , lag(chomebanking_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as chomebanking_transacciones_lag_3
#     , lag(ccajas_transacciones, 3) over (partition by numero_de_cliente order by foto_mes) as ccajas_transacciones_lag_3
#     , lag(ccajas_consultas, 3) over (partition by numero_de_cliente order by foto_mes) as ccajas_consultas_lag_3
#     , lag(ccajas_depositos, 3) over (partition by numero_de_cliente order by foto_mes) as ccajas_depositos_lag_3
#     , lag(ccajas_extracciones, 3) over (partition by numero_de_cliente order by foto_mes) as ccajas_extracciones_lag_3
#     , lag(ccajas_otras, 3) over (partition by numero_de_cliente order by foto_mes) as ccajas_otras_lag_3
#     , lag(catm_trx, 3) over (partition by numero_de_cliente order by foto_mes) as catm_trx_lag_3
#     , lag(matm_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as matm_sin_drif_lag_3
#     , lag(catm_trx_other, 3) over (partition by numero_de_cliente order by foto_mes) as catm_trx_other_lag_3
#     , lag(matm_other_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as matm_other_sin_drif_lag_3
#     , lag(ctrx_quarter, 3) over (partition by numero_de_cliente order by foto_mes) as ctrx_quarter_lag_3
#     , lag(Master_delinquency, 3) over (partition by numero_de_cliente order by foto_mes) as Master_delinquency_lag_3
#     , lag(Master_status, 3) over (partition by numero_de_cliente order by foto_mes) as Master_status_lag_3
#     , lag(Master_mfinanciacion_limite_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mfinanciacion_limite_sin_drif_lag_3
#     , lag(Master_Fvencimiento, 3) over (partition by numero_de_cliente order by foto_mes) as Master_Fvencimiento_lag_3
#     , lag(Master_Finiciomora, 3) over (partition by numero_de_cliente order by foto_mes) as Master_Finiciomora_lag_3
#     , lag(Master_msaldototal_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_msaldototal_sin_drif_lag_3
#     , lag(Master_msaldopesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_msaldopesos_sin_drif_lag_3
#     , lag(Master_msaldodolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_msaldodolares_sin_drif_lag_3
#     , lag(Master_mconsumospesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumospesos_sin_drif_lag_3
#     , lag(Master_mconsumosdolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumosdolares_sin_drif_lag_3
#     , lag(Master_mlimitecompra_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mlimitecompra_sin_drif_lag_3
#     , lag(Master_madelantopesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_madelantopesos_sin_drif_lag_3
#     , lag(Master_madelantodolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_madelantodolares_sin_drif_lag_3
#     , lag(Master_fultimo_cierre, 3) over (partition by numero_de_cliente order by foto_mes) as Master_fultimo_cierre_lag_3
#     , lag(Master_mpagado_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mpagado_sin_drif_lag_3
#     , lag(Master_mpagospesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mpagospesos_sin_drif_lag_3
#     , lag(Master_mpagosdolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mpagosdolares_sin_drif_lag_3
#     , lag(Master_fechaalta, 3) over (partition by numero_de_cliente order by foto_mes) as Master_fechaalta_lag_3
#     , lag(Master_mconsumototal_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumototal_sin_drif_lag_3
#     , lag(Master_cconsumos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_cconsumos_sin_drif_lag_3
#     , lag(Master_cadelantosefectivo, 3) over (partition by numero_de_cliente order by foto_mes) as Master_cadelantosefectivo_lag_3
#     , lag(Master_mpagominimo_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Master_mpagominimo_sin_drif_lag_3
#     , lag(Visa_delinquency, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_delinquency_lag_3
#     , lag(Visa_status, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_status_lag_3
#     , lag(Visa_mfinanciacion_limite_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mfinanciacion_limite_sin_drif_lag_3
#     , lag(Visa_Fvencimiento, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_Fvencimiento_lag_3
#     , lag(Visa_Finiciomora, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_Finiciomora_lag_3
#     , lag(Visa_msaldototal_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldototal_sin_drif_lag_3
#     , lag(Visa_msaldopesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldopesos_sin_drif_lag_3
#     , lag(Visa_msaldodolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldodolares_sin_drif_lag_3
#     , lag(Visa_mconsumospesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumospesos_sin_drif_lag_3
#     , lag(Visa_mconsumosdolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumosdolares_sin_drif_lag_3
#     , lag(Visa_mlimitecompra_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mlimitecompra_sin_drif_lag_3
#     , lag(Visa_madelantopesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantopesos_sin_drif_lag_3
#     , lag(Visa_madelantodolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantodolares_sin_drif_lag_3
#     , lag(Visa_fultimo_cierre, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_fultimo_cierre_lag_3
#     , lag(Visa_mpagado_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagado_sin_drif_lag_3
#     , lag(Visa_mpagospesos_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagospesos_sin_drif_lag_3
#     , lag(Visa_mpagosdolares_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagosdolares_sin_drif_lag_3
#     , lag(Visa_fechaalta, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_fechaalta_lag_3
#     , lag(Visa_mconsumototal_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumototal_sin_drif_lag_3
#     , lag(Visa_cconsumos, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_cconsumos_lag_3
#     , lag(Visa_cadelantosefectivo, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_cadelantosefectivo_lag_3
#     , lag(Visa_mpagominimo_sin_drif, 3) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagominimo_sin_drif_lag_3
#
#
#     , lag(active_quarter, 6) over (partition by numero_de_cliente order by foto_mes) as active_quarter_lag_6
#     , lag(cliente_vip, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_vip_lag_6
#     , lag(internet, 6) over (partition by numero_de_cliente order by foto_mes) as internet_lag_6
#     , lag(cliente_edad, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_edad_lag_6
#     , lag(cliente_antiguedad, 6) over (partition by numero_de_cliente order by foto_mes) as cliente_antiguedad_lag_6
#     , lag(mrentabilidad_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_sin_drif_lag_6
#     , lag(mrentabilidad_annual_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mrentabilidad_annual_sin_drif_lag_6
#     , lag(mcomisiones_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_sin_drif_lag_6
#     , lag(mactivos_margen_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mactivos_margen_sin_drif_lag_6
#     , lag(mpasivos_margen_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mpasivos_margen_sin_drif_lag_6
#     , lag(cproductos, 6) over (partition by numero_de_cliente order by foto_mes) as cproductos_lag_6
#     , lag(tcuentas, 6) over (partition by numero_de_cliente order by foto_mes) as tcuentas_lag_6
#     , lag(ccuenta_corriente, 6) over (partition by numero_de_cliente order by foto_mes) as ccuenta_corriente_lag_6
#     , lag(mcuenta_corriente_adicional_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_adicional_sin_drif_lag_6
#     , lag(mcuenta_corriente_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcuenta_corriente_sin_drif_lag_6
#     , lag(ccaja_ahorro, 6) over (partition by numero_de_cliente order by foto_mes) as ccaja_ahorro_lag_6
#     , lag(mcaja_ahorro_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_sin_drif_lag_6
#     , lag(mcaja_ahorro_adicional_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_adicional_sin_drif_lag_6
#     , lag(mcaja_ahorro_dolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcaja_ahorro_dolares_sin_drif_lag_6
#     , lag(cdescubierto_preacordado, 6) over (partition by numero_de_cliente order by foto_mes) as cdescubierto_preacordado_lag_6
#     , lag(mcuentas_saldo_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcuentas_saldo_sin_drif_lag_6
#     , lag(ctarjeta_debito, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_lag_6
#     , lag(ctarjeta_debito_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_debito_transacciones_lag_6
#     , lag(mautoservicio_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mautoservicio_sin_drif_lag_6
#     , lag(ctarjeta_visa, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_lag_6
#     , lag(ctarjeta_visa_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_transacciones_lag_6
#     , lag(mtarjeta_visa_consumo_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_consumo_sin_drif_lag_6
#     , lag(ctarjeta_master, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_lag_6
#     , lag(ctarjeta_master_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_transacciones_lag_6
#     , lag(mtarjeta_master_consumo_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_consumo_sin_drif_lag_6
#     , lag(cprestamos_personales, 6) over (partition by numero_de_cliente order by foto_mes) as cprestamos_personales_lag_6
#     , lag(mprestamos_personales_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mprestamos_personales_sin_drif_lag_6
#     , lag(cprestamos_prendarios, 6) over (partition by numero_de_cliente order by foto_mes) as cprestamos_prendarios_lag_6
#     , lag(mprestamos_prendarios_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mprestamos_prendarios_sin_drif_lag_6
#     , lag(cprestamos_hipotecarios, 6) over (partition by numero_de_cliente order by foto_mes) as cprestamos_hipotecarios_lag_6
#     , lag(mprestamos_hipotecarios_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mprestamos_hipotecarios_sin_drif_lag_6
#     , lag(cplazo_fijo, 6) over (partition by numero_de_cliente order by foto_mes) as cplazo_fijo_lag_6
#     , lag(mplazo_fijo_dolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_dolares_sin_drif_lag_6
#     , lag(mplazo_fijo_pesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mplazo_fijo_pesos_sin_drif_lag_6
#     , lag(cinversion1, 6) over (partition by numero_de_cliente order by foto_mes) as cinversion1_lag_6
#     , lag(minversion1_pesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as minversion1_pesos_sin_drif_lag_6
#     , lag(minversion1_dolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as minversion1_dolares_sin_drif_lag_6
#     , lag(cinversion2, 6) over (partition by numero_de_cliente order by foto_mes) as cinversion2_lag_6
#     , lag(minversion2_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as minversion2_sin_drif_lag_6
#     , lag(cseguro_vida, 6) over (partition by numero_de_cliente order by foto_mes) as cseguro_vida_lag_6
#     , lag(cseguro_auto, 6) over (partition by numero_de_cliente order by foto_mes) as cseguro_auto_lag_6
#     , lag(cseguro_vivienda, 6) over (partition by numero_de_cliente order by foto_mes) as cseguro_vivienda_lag_6
#     , lag(cseguro_accidentes_personales, 6) over (partition by numero_de_cliente order by foto_mes) as cseguro_accidentes_personales_lag_6
#     , lag(ccaja_seguridad, 6) over (partition by numero_de_cliente order by foto_mes) as ccaja_seguridad_lag_6
#     , lag(cpayroll_trx, 6) over (partition by numero_de_cliente order by foto_mes) as cpayroll_trx_lag_6
#     , lag(mpayroll_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mpayroll_sin_drif_lag_6
#     , lag(mpayroll2_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mpayroll2_sin_drif_lag_6
#     , lag(cpayroll2_trx, 6) over (partition by numero_de_cliente order by foto_mes) as cpayroll2_trx_lag_6
#     , lag(ccuenta_debitos_automaticos, 6) over (partition by numero_de_cliente order by foto_mes) as ccuenta_debitos_automaticos_lag_6
#     , lag(mcuenta_debitos_automaticos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcuenta_debitos_automaticos_sin_drif_lag_6
#     , lag(ctarjeta_visa_debitos_automaticos, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_debitos_automaticos_lag_6
#     , lag(mttarjeta_visa_debitos_automaticos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_visa_debitos_automaticos_sin_drif_lag_6
#     , lag(ctarjeta_master_debitos_automaticos, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_debitos_automaticos_lag_6
#     , lag(mttarjeta_master_debitos_automaticos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mttarjeta_master_debitos_automaticos_sin_drif_lag_6
#     , lag(cpagodeservicios, 6) over (partition by numero_de_cliente order by foto_mes) as cpagodeservicios_lag_6
#     , lag(mpagodeservicios_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mpagodeservicios_sin_drif_lag_6
#     , lag(cpagomiscuentas, 6) over (partition by numero_de_cliente order by foto_mes) as cpagomiscuentas_lag_6
#     , lag(mpagomiscuentas_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mpagomiscuentas_sin_drif_lag_6
#     , lag(ccajeros_propios_descuentos, 6) over (partition by numero_de_cliente order by foto_mes) as ccajeros_propios_descuentos_lag_6
#     , lag(mcajeros_propios_descuentos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcajeros_propios_descuentos_sin_drif_lag_6
#     , lag(ctarjeta_visa_descuentos, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_visa_descuentos_lag_6
#     , lag(mtarjeta_visa_descuentos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_visa_descuentos_sin_drif_lag_6
#     , lag(ctarjeta_master_descuentos, 6) over (partition by numero_de_cliente order by foto_mes) as ctarjeta_master_descuentos_lag_6
#     , lag(mtarjeta_master_descuentos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtarjeta_master_descuentos_sin_drif_lag_6
#     , lag(ccomisiones_mantenimiento, 6) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_mantenimiento_lag_6
#     , lag(mcomisiones_mantenimiento_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_mantenimiento_sin_drif_lag_6
#     , lag(ccomisiones_otras, 6) over (partition by numero_de_cliente order by foto_mes) as ccomisiones_otras_lag_6
#     , lag(mcomisiones_otras_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcomisiones_otras_sin_drif_lag_6
#     , lag(cforex, 6) over (partition by numero_de_cliente order by foto_mes) as cforex_lag_6
#     , lag(cforex_buy, 6) over (partition by numero_de_cliente order by foto_mes) as cforex_buy_lag_6
#     , lag(mforex_buy_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mforex_buy_sin_drif_lag_6
#     , lag(cforex_sell, 6) over (partition by numero_de_cliente order by foto_mes) as cforex_sell_lag_6
#     , lag(mforex_sell_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mforex_sell_sin_drif_lag_6
#     , lag(ctransferencias_recibidas, 6) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_recibidas_lag_6
#     , lag(mtransferencias_recibidas_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_recibidas_sin_drif_lag_6
#     , lag(ctransferencias_emitidas, 6) over (partition by numero_de_cliente order by foto_mes) as ctransferencias_emitidas_lag_6
#     , lag(mtransferencias_emitidas_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mtransferencias_emitidas_sin_drif_lag_6
#     , lag(cextraccion_autoservicio, 6) over (partition by numero_de_cliente order by foto_mes) as cextraccion_autoservicio_lag_6
#     , lag(mextraccion_autoservicio_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mextraccion_autoservicio_sin_drif_lag_6
#     , lag(ccheques_depositados, 6) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_lag_6
#     , lag(mcheques_depositados_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_sin_drif_lag_6
#     , lag(ccheques_emitidos, 6) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_lag_6
#     , lag(mcheques_emitidos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_sin_drif_lag_6
#     , lag(ccheques_depositados_rechazados, 6) over (partition by numero_de_cliente order by foto_mes) as ccheques_depositados_rechazados_lag_6
#     , lag(mcheques_depositados_rechazados_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcheques_depositados_rechazados_sin_drif_lag_6
#     , lag(ccheques_emitidos_rechazados, 6) over (partition by numero_de_cliente order by foto_mes) as ccheques_emitidos_rechazados_lag_6
#     , lag(mcheques_emitidos_rechazados_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as mcheques_emitidos_rechazados_sin_drif_lag_6
#     , lag(tcallcenter, 6) over (partition by numero_de_cliente order by foto_mes) as tcallcenter_lag_6
#     , lag(ccallcenter_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as ccallcenter_transacciones_lag_6
#     , lag(thomebanking, 6) over (partition by numero_de_cliente order by foto_mes) as thomebanking_lag_6
#     , lag(chomebanking_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as chomebanking_transacciones_lag_6
#     , lag(ccajas_transacciones, 6) over (partition by numero_de_cliente order by foto_mes) as ccajas_transacciones_lag_6
#     , lag(ccajas_consultas, 6) over (partition by numero_de_cliente order by foto_mes) as ccajas_consultas_lag_6
#     , lag(ccajas_depositos, 6) over (partition by numero_de_cliente order by foto_mes) as ccajas_depositos_lag_6
#     , lag(ccajas_extracciones, 6) over (partition by numero_de_cliente order by foto_mes) as ccajas_extracciones_lag_6
#     , lag(ccajas_otras, 6) over (partition by numero_de_cliente order by foto_mes) as ccajas_otras_lag_6
#     , lag(catm_trx, 6) over (partition by numero_de_cliente order by foto_mes) as catm_trx_lag_6
#     , lag(matm_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as matm_sin_drif_lag_6
#     , lag(catm_trx_other, 6) over (partition by numero_de_cliente order by foto_mes) as catm_trx_other_lag_6
#     , lag(matm_other_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as matm_other_sin_drif_lag_6
#     , lag(ctrx_quarter, 6) over (partition by numero_de_cliente order by foto_mes) as ctrx_quarter_lag_6
#     , lag(Master_delinquency, 6) over (partition by numero_de_cliente order by foto_mes) as Master_delinquency_lag_6
#     , lag(Master_status, 6) over (partition by numero_de_cliente order by foto_mes) as Master_status_lag_6
#     , lag(Master_mfinanciacion_limite_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mfinanciacion_limite_sin_drif_lag_6
#     , lag(Master_Fvencimiento, 6) over (partition by numero_de_cliente order by foto_mes) as Master_Fvencimiento_lag_6
#     , lag(Master_Finiciomora, 6) over (partition by numero_de_cliente order by foto_mes) as Master_Finiciomora_lag_6
#     , lag(Master_msaldototal_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_msaldototal_sin_drif_lag_6
#     , lag(Master_msaldopesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_msaldopesos_sin_drif_lag_6
#     , lag(Master_msaldodolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_msaldodolares_sin_drif_lag_6
#     , lag(Master_mconsumospesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumospesos_sin_drif_lag_6
#     , lag(Master_mconsumosdolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumosdolares_sin_drif_lag_6
#     , lag(Master_mlimitecompra_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mlimitecompra_sin_drif_lag_6
#     , lag(Master_madelantopesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_madelantopesos_sin_drif_lag_6
#     , lag(Master_madelantodolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_madelantodolares_sin_drif_lag_6
#     , lag(Master_fultimo_cierre, 6) over (partition by numero_de_cliente order by foto_mes) as Master_fultimo_cierre_lag_6
#     , lag(Master_mpagado_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mpagado_sin_drif_lag_6
#     , lag(Master_mpagospesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mpagospesos_sin_drif_lag_6
#     , lag(Master_mpagosdolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mpagosdolares_sin_drif_lag_6
#     , lag(Master_fechaalta, 6) over (partition by numero_de_cliente order by foto_mes) as Master_fechaalta_lag_6
#     , lag(Master_mconsumototal_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mconsumototal_sin_drif_lag_6
#     , lag(Master_cconsumos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_cconsumos_sin_drif_lag_6
#     , lag(Master_cadelantosefectivo, 6) over (partition by numero_de_cliente order by foto_mes) as Master_cadelantosefectivo_lag_6
#     , lag(Master_mpagominimo_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Master_mpagominimo_sin_drif_lag_6
#     , lag(Visa_delinquency, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_delinquency_lag_6
#     , lag(Visa_status, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_status_lag_6
#     , lag(Visa_mfinanciacion_limite_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mfinanciacion_limite_sin_drif_lag_6
#     , lag(Visa_Fvencimiento, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_Fvencimiento_lag_6
#     , lag(Visa_Finiciomora, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_Finiciomora_lag_6
#     , lag(Visa_msaldototal_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldototal_sin_drif_lag_6
#     , lag(Visa_msaldopesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldopesos_sin_drif_lag_6
#     , lag(Visa_msaldodolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_msaldodolares_sin_drif_lag_6
#     , lag(Visa_mconsumospesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumospesos_sin_drif_lag_6
#     , lag(Visa_mconsumosdolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumosdolares_sin_drif_lag_6
#     , lag(Visa_mlimitecompra_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mlimitecompra_sin_drif_lag_6
#     , lag(Visa_madelantopesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantopesos_sin_drif_lag_6
#     , lag(Visa_madelantodolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_madelantodolares_sin_drif_lag_6
#     , lag(Visa_fultimo_cierre, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_fultimo_cierre_lag_6
#     , lag(Visa_mpagado_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagado_sin_drif_lag_6
#     , lag(Visa_mpagospesos_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagospesos_sin_drif_lag_6
#     , lag(Visa_mpagosdolares_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagosdolares_sin_drif_lag_6
#     , lag(Visa_fechaalta, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_fechaalta_lag_6
#     , lag(Visa_mconsumototal_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mconsumototal_sin_drif_lag_6
#     , lag(Visa_cconsumos, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_cconsumos_lag_6
#     , lag(Visa_cadelantosefectivo, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_cadelantosefectivo_lag_6
#     , lag(Visa_mpagominimo_sin_drif, 6) over (partition by numero_de_cliente order by foto_mes) as Visa_mpagominimo_sin_drif_lag_6
#
#     , regr_slope(active_quarter, cliente_antiguedad) over ventana_6 as active_quarter_slope_6
#     , regr_slope(cliente_vip, cliente_antiguedad) over ventana_6 as cliente_vip_slope_6
#     , regr_slope(internet, cliente_antiguedad) over ventana_6 as internet_slope_6
#     , regr_slope(cliente_edad, cliente_antiguedad) over ventana_6 as cliente_edad_slope_6
#     , regr_slope(cliente_antiguedad, cliente_antiguedad) over ventana_6 as cliente_antiguedad_slope_6
#     , regr_slope(mrentabilidad_sin_drif, cliente_antiguedad) over ventana_6 as mrentabilidad_sin_drif_slope_6
#     , regr_slope(mrentabilidad_annual_sin_drif, cliente_antiguedad) over ventana_6 as mrentabilidad_annual_sin_drif_slope_6
#     , regr_slope(mcomisiones_sin_drif, cliente_antiguedad) over ventana_6 as mcomisiones_sin_drif_slope_6
#     , regr_slope(mactivos_margen_sin_drif, cliente_antiguedad) over ventana_6 as mactivos_margen_sin_drif_slope_6
#     , regr_slope(mpasivos_margen_sin_drif, cliente_antiguedad) over ventana_6 as mpasivos_margen_sin_drif_slope_6
#     , regr_slope(cproductos, cliente_antiguedad) over ventana_6 as cproductos_slope_6
#     , regr_slope(tcuentas, cliente_antiguedad) over ventana_6 as tcuentas_slope_6
#     , regr_slope(ccuenta_corriente, cliente_antiguedad) over ventana_6 as ccuenta_corriente_slope_6
#     , regr_slope(mcuenta_corriente_adicional_sin_drif, cliente_antiguedad) over ventana_6 as mcuenta_corriente_adicional_sin_drif_slope_6
#     , regr_slope(mcuenta_corriente_sin_drif, cliente_antiguedad) over ventana_6 as mcuenta_corriente_sin_drif_slope_6
#     , regr_slope(ccaja_ahorro, cliente_antiguedad) over ventana_6 as ccaja_ahorro_slope_6
#     , regr_slope(mcaja_ahorro_sin_drif, cliente_antiguedad) over ventana_6 as mcaja_ahorro_sin_drif_slope_6
#     , regr_slope(mcaja_ahorro_adicional_sin_drif, cliente_antiguedad) over ventana_6 as mcaja_ahorro_adicional_sin_drif_slope_6
#     , regr_slope(mcaja_ahorro_dolares_sin_drif, cliente_antiguedad) over ventana_6 as mcaja_ahorro_dolares_sin_drif_slope_6
#     , regr_slope(cdescubierto_preacordado, cliente_antiguedad) over ventana_6 as cdescubierto_preacordado_slope_6
#     , regr_slope(mcuentas_saldo_sin_drif, cliente_antiguedad) over ventana_6 as mcuentas_saldo_sin_drif_slope_6
#     , regr_slope(ctarjeta_debito, cliente_antiguedad) over ventana_6 as ctarjeta_debito_slope_6
#     , regr_slope(ctarjeta_debito_transacciones, cliente_antiguedad) over ventana_6 as ctarjeta_debito_transacciones_slope_6
#     , regr_slope(mautoservicio_sin_drif, cliente_antiguedad) over ventana_6 as mautoservicio_sin_drif_slope_6
#     , regr_slope(ctarjeta_visa, cliente_antiguedad) over ventana_6 as ctarjeta_visa_slope_6
#     , regr_slope(ctarjeta_visa_transacciones, cliente_antiguedad) over ventana_6 as ctarjeta_visa_transacciones_slope_6
#     , regr_slope(mtarjeta_visa_consumo_sin_drif, cliente_antiguedad) over ventana_6 as mtarjeta_visa_consumo_sin_drif_slope_6
#     , regr_slope(ctarjeta_master, cliente_antiguedad) over ventana_6 as ctarjeta_master_slope_6
#     , regr_slope(ctarjeta_master_transacciones, cliente_antiguedad) over ventana_6 as ctarjeta_master_transacciones_slope_6
#     , regr_slope(mtarjeta_master_consumo_sin_drif, cliente_antiguedad) over ventana_6 as mtarjeta_master_consumo_sin_drif_slope_6
#     , regr_slope(cprestamos_personales, cliente_antiguedad) over ventana_6 as cprestamos_personales_slope_6
#     , regr_slope(mprestamos_personales_sin_drif, cliente_antiguedad) over ventana_6 as mprestamos_personales_sin_drif_slope_6
#     , regr_slope(cprestamos_prendarios, cliente_antiguedad) over ventana_6 as cprestamos_prendarios_slope_6
#     , regr_slope(mprestamos_prendarios_sin_drif, cliente_antiguedad) over ventana_6 as mprestamos_prendarios_sin_drif_slope_6
#     , regr_slope(cprestamos_hipotecarios, cliente_antiguedad) over ventana_6 as cprestamos_hipotecarios_slope_6
#     , regr_slope(mprestamos_hipotecarios_sin_drif, cliente_antiguedad) over ventana_6 as mprestamos_hipotecarios_sin_drif_slope_6
#     , regr_slope(cplazo_fijo, cliente_antiguedad) over ventana_6 as cplazo_fijo_slope_6
#     , regr_slope(mplazo_fijo_dolares_sin_drif, cliente_antiguedad) over ventana_6 as mplazo_fijo_dolares_sin_drif_slope_6
#     , regr_slope(mplazo_fijo_pesos_sin_drif, cliente_antiguedad) over ventana_6 as mplazo_fijo_pesos_sin_drif_slope_6
#     , regr_slope(cinversion1, cliente_antiguedad) over ventana_6 as cinversion1_slope_6
#     , regr_slope(minversion1_pesos_sin_drif, cliente_antiguedad) over ventana_6 as minversion1_pesos_sin_drif_slope_6
#     , regr_slope(minversion1_dolares_sin_drif, cliente_antiguedad) over ventana_6 as minversion1_dolares_sin_drif_slope_6
#     , regr_slope(cinversion2, cliente_antiguedad) over ventana_6 as cinversion2_slope_6
#     , regr_slope(minversion2_sin_drif, cliente_antiguedad) over ventana_6 as minversion2_sin_drif_slope_6
#     , regr_slope(cseguro_vida, cliente_antiguedad) over ventana_6 as cseguro_vida_slope_6
#     , regr_slope(cseguro_auto, cliente_antiguedad) over ventana_6 as cseguro_auto_slope_6
#     , regr_slope(cseguro_vivienda, cliente_antiguedad) over ventana_6 as cseguro_vivienda_slope_6
#     , regr_slope(cseguro_accidentes_personales, cliente_antiguedad) over ventana_6 as cseguro_accidentes_personales_slope_6
#     , regr_slope(ccaja_seguridad, cliente_antiguedad) over ventana_6 as ccaja_seguridad_slope_6
#     , regr_slope(cpayroll_trx, cliente_antiguedad) over ventana_6 as cpayroll_trx_slope_6
#     , regr_slope(mpayroll_sin_drif, cliente_antiguedad) over ventana_6 as mpayroll_sin_drif_slope_6
#     , regr_slope(mpayroll2_sin_drif, cliente_antiguedad) over ventana_6 as mpayroll2_sin_drif_slope_6
#     , regr_slope(cpayroll2_trx, cliente_antiguedad) over ventana_6 as cpayroll2_trx_slope_6
#     , regr_slope(ccuenta_debitos_automaticos, cliente_antiguedad) over ventana_6 as ccuenta_debitos_automaticos_slope_6
#     , regr_slope(mcuenta_debitos_automaticos_sin_drif, cliente_antiguedad) over ventana_6 as mcuenta_debitos_automaticos_sin_drif_slope_6
#     , regr_slope(ctarjeta_visa_debitos_automaticos, cliente_antiguedad) over ventana_6 as ctarjeta_visa_debitos_automaticos_slope_6
#     , regr_slope(mttarjeta_visa_debitos_automaticos_sin_drif, cliente_antiguedad) over ventana_6 as mttarjeta_visa_debitos_automaticos_sin_drif_slope_6
#     , regr_slope(ctarjeta_master_debitos_automaticos, cliente_antiguedad) over ventana_6 as ctarjeta_master_debitos_automaticos_slope_6
#     , regr_slope(mttarjeta_master_debitos_automaticos_sin_drif, cliente_antiguedad) over ventana_6 as mttarjeta_master_debitos_automaticos_sin_drif_slope_6
#     , regr_slope(cpagodeservicios, cliente_antiguedad) over ventana_6 as cpagodeservicios_slope_6
#     , regr_slope(mpagodeservicios_sin_drif, cliente_antiguedad) over ventana_6 as mpagodeservicios_sin_drif_slope_6
#     , regr_slope(cpagomiscuentas, cliente_antiguedad) over ventana_6 as cpagomiscuentas_slope_6
#     , regr_slope(mpagomiscuentas_sin_drif, cliente_antiguedad) over ventana_6 as mpagomiscuentas_sin_drif_slope_6
#     , regr_slope(ccajeros_propios_descuentos, cliente_antiguedad) over ventana_6 as ccajeros_propios_descuentos_slope_6
#     , regr_slope(mcajeros_propios_descuentos_sin_drif, cliente_antiguedad) over ventana_6 as mcajeros_propios_descuentos_sin_drif_slope_6
#     , regr_slope(ctarjeta_visa_descuentos, cliente_antiguedad) over ventana_6 as ctarjeta_visa_descuentos_slope_6
#     , regr_slope(mtarjeta_visa_descuentos_sin_drif, cliente_antiguedad) over ventana_6 as mtarjeta_visa_descuentos_sin_drif_slope_6
#     , regr_slope(ctarjeta_master_descuentos, cliente_antiguedad) over ventana_6 as ctarjeta_master_descuentos_slope_6
#     , regr_slope(mtarjeta_master_descuentos_sin_drif, cliente_antiguedad) over ventana_6 as mtarjeta_master_descuentos_sin_drif_slope_6
#     , regr_slope(ccomisiones_mantenimiento, cliente_antiguedad) over ventana_6 as ccomisiones_mantenimiento_slope_6
#     , regr_slope(mcomisiones_mantenimiento_sin_drif, cliente_antiguedad) over ventana_6 as mcomisiones_mantenimiento_sin_drif_slope_6
#     , regr_slope(ccomisiones_otras, cliente_antiguedad) over ventana_6 as ccomisiones_otras_slope_6
#     , regr_slope(mcomisiones_otras_sin_drif, cliente_antiguedad) over ventana_6 as mcomisiones_otras_sin_drif_slope_6
#     , regr_slope(cforex, cliente_antiguedad) over ventana_6 as cforex_slope_6
#     , regr_slope(cforex_buy, cliente_antiguedad) over ventana_6 as cforex_buy_slope_6
#     , regr_slope(mforex_buy_sin_drif, cliente_antiguedad) over ventana_6 as mforex_buy_sin_drif_slope_6
#     , regr_slope(cforex_sell, cliente_antiguedad) over ventana_6 as cforex_sell_slope_6
#     , regr_slope(mforex_sell_sin_drif, cliente_antiguedad) over ventana_6 as mforex_sell_sin_drif_slope_6
#     , regr_slope(ctransferencias_recibidas, cliente_antiguedad) over ventana_6 as ctransferencias_recibidas_slope_6
#     , regr_slope(mtransferencias_recibidas_sin_drif, cliente_antiguedad) over ventana_6 as mtransferencias_recibidas_sin_drif_slope_6
#     , regr_slope(ctransferencias_emitidas, cliente_antiguedad) over ventana_6 as ctransferencias_emitidas_slope_6
#     , regr_slope(mtransferencias_emitidas_sin_drif, cliente_antiguedad) over ventana_6 as mtransferencias_emitidas_sin_drif_slope_6
#     , regr_slope(cextraccion_autoservicio, cliente_antiguedad) over ventana_6 as cextraccion_autoservicio_slope_6
#     , regr_slope(mextraccion_autoservicio_sin_drif, cliente_antiguedad) over ventana_6 as mextraccion_autoservicio_sin_drif_slope_6
#     , regr_slope(ccheques_depositados, cliente_antiguedad) over ventana_6 as ccheques_depositados_slope_6
#     , regr_slope(mcheques_depositados_sin_drif, cliente_antiguedad) over ventana_6 as mcheques_depositados_sin_drif_slope_6
#     , regr_slope(ccheques_emitidos, cliente_antiguedad) over ventana_6 as ccheques_emitidos_slope_6
#     , regr_slope(mcheques_emitidos_sin_drif, cliente_antiguedad) over ventana_6 as mcheques_emitidos_sin_drif_slope_6
#     , regr_slope(ccheques_depositados_rechazados, cliente_antiguedad) over ventana_6 as ccheques_depositados_rechazados_slope_6
#     , regr_slope(mcheques_depositados_rechazados_sin_drif, cliente_antiguedad) over ventana_6 as mcheques_depositados_rechazados_sin_drif_slope_6
#     , regr_slope(ccheques_emitidos_rechazados, cliente_antiguedad) over ventana_6 as ccheques_emitidos_rechazados_slope_6
#     , regr_slope(mcheques_emitidos_rechazados_sin_drif, cliente_antiguedad) over ventana_6 as mcheques_emitidos_rechazados_sin_drif_slope_6
#     , regr_slope(tcallcenter, cliente_antiguedad) over ventana_6 as tcallcenter_slope_6
#     , regr_slope(ccallcenter_transacciones, cliente_antiguedad) over ventana_6 as ccallcenter_transacciones_slope_6
#     , regr_slope(thomebanking, cliente_antiguedad) over ventana_6 as thomebanking_slope_6
#     , regr_slope(chomebanking_transacciones, cliente_antiguedad) over ventana_6 as chomebanking_transacciones_slope_6
#     , regr_slope(ccajas_transacciones, cliente_antiguedad) over ventana_6 as ccajas_transacciones_slope_6
#     , regr_slope(ccajas_consultas, cliente_antiguedad) over ventana_6 as ccajas_consultas_slope_6
#     , regr_slope(ccajas_depositos, cliente_antiguedad) over ventana_6 as ccajas_depositos_slope_6
#     , regr_slope(ccajas_extracciones, cliente_antiguedad) over ventana_6 as ccajas_extracciones_slope_6
#     , regr_slope(ccajas_otras, cliente_antiguedad) over ventana_6 as ccajas_otras_slope_6
#     , regr_slope(catm_trx, cliente_antiguedad) over ventana_6 as catm_trx_slope_6
#     , regr_slope(matm_sin_drif, cliente_antiguedad) over ventana_6 as matm_sin_drif_slope_6
#     , regr_slope(catm_trx_other, cliente_antiguedad) over ventana_6 as catm_trx_other_slope_6
#     , regr_slope(matm_other_sin_drif, cliente_antiguedad) over ventana_6 as matm_other_sin_drif_slope_6
#     , regr_slope(ctrx_quarter, cliente_antiguedad) over ventana_6 as ctrx_quarter_slope_6
#     , regr_slope(Master_delinquency, cliente_antiguedad) over ventana_6 as Master_delinquency_slope_6
#     , regr_slope(Master_status, cliente_antiguedad) over ventana_6 as Master_status_slope_6
#     , regr_slope(Master_mfinanciacion_limite_sin_drif, cliente_antiguedad) over ventana_6 as Master_mfinanciacion_limite_sin_drif_slope_6
#     , regr_slope(Master_Fvencimiento, cliente_antiguedad) over ventana_6 as Master_Fvencimiento_slope_6
#     , regr_slope(Master_Finiciomora, cliente_antiguedad) over ventana_6 as Master_Finiciomora_slope_6
#     , regr_slope(Master_msaldototal_sin_drif, cliente_antiguedad) over ventana_6 as Master_msaldototal_sin_drif_slope_6
#     , regr_slope(Master_msaldopesos_sin_drif, cliente_antiguedad) over ventana_6 as Master_msaldopesos_sin_drif_slope_6
#     , regr_slope(Master_msaldodolares_sin_drif, cliente_antiguedad) over ventana_6 as Master_msaldodolares_sin_drif_slope_6
#     , regr_slope(Master_mconsumospesos_sin_drif, cliente_antiguedad) over ventana_6 as Master_mconsumospesos_sin_drif_slope_6
#     , regr_slope(Master_mconsumosdolares_sin_drif, cliente_antiguedad) over ventana_6 as Master_mconsumosdolares_sin_drif_slope_6
#     , regr_slope(Master_mlimitecompra_sin_drif, cliente_antiguedad) over ventana_6 as Master_mlimitecompra_sin_drif_slope_6
#     , regr_slope(Master_madelantopesos_sin_drif, cliente_antiguedad) over ventana_6 as Master_madelantopesos_sin_drif_slope_6
#     , regr_slope(Master_madelantodolares_sin_drif, cliente_antiguedad) over ventana_6 as Master_madelantodolares_sin_drif_slope_6
#     , regr_slope(Master_fultimo_cierre, cliente_antiguedad) over ventana_6 as Master_fultimo_cierre_slope_6
#     , regr_slope(Master_mpagado_sin_drif, cliente_antiguedad) over ventana_6 as Master_mpagado_sin_drif_slope_6
#     , regr_slope(Master_mpagospesos_sin_drif, cliente_antiguedad) over ventana_6 as Master_mpagospesos_sin_drif_slope_6
#     , regr_slope(Master_mpagosdolares_sin_drif, cliente_antiguedad) over ventana_6 as Master_mpagosdolares_sin_drif_slope_6
#     , regr_slope(Master_fechaalta, cliente_antiguedad) over ventana_6 as Master_fechaalta_slope_6
#     , regr_slope(Master_mconsumototal_sin_drif, cliente_antiguedad) over ventana_6 as Master_mconsumototal_sin_drif_slope_6
#     , regr_slope(Master_cconsumos_sin_drif, cliente_antiguedad) over ventana_6 as Master_cconsumos_sin_drif_slope_6
#     , regr_slope(Master_cadelantosefectivo, cliente_antiguedad) over ventana_6 as Master_cadelantosefectivo_slope_6
#     , regr_slope(Master_mpagominimo_sin_drif, cliente_antiguedad) over ventana_6 as Master_mpagominimo_sin_drif_slope_6
#     , regr_slope(Visa_delinquency, cliente_antiguedad) over ventana_6 as Visa_delinquency_slope_6
#     , regr_slope(Visa_status, cliente_antiguedad) over ventana_6 as Visa_status_slope_6
#     , regr_slope(Visa_mfinanciacion_limite_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mfinanciacion_limite_sin_drif_slope_6
#     , regr_slope(Visa_Fvencimiento, cliente_antiguedad) over ventana_6 as Visa_Fvencimiento_slope_6
#     , regr_slope(Visa_Finiciomora, cliente_antiguedad) over ventana_6 as Visa_Finiciomora_slope_6
#     , regr_slope(Visa_msaldototal_sin_drif, cliente_antiguedad) over ventana_6 as Visa_msaldototal_sin_drif_slope_6
#     , regr_slope(Visa_msaldopesos_sin_drif, cliente_antiguedad) over ventana_6 as Visa_msaldopesos_sin_drif_slope_6
#     , regr_slope(Visa_msaldodolares_sin_drif, cliente_antiguedad) over ventana_6 as Visa_msaldodolares_sin_drif_slope_6
#     , regr_slope(Visa_mconsumospesos_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mconsumospesos_sin_drif_slope_6
#     , regr_slope(Visa_mconsumosdolares_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mconsumosdolares_sin_drif_slope_6
#     , regr_slope(Visa_mlimitecompra_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mlimitecompra_sin_drif_slope_6
#     , regr_slope(Visa_madelantopesos_sin_drif, cliente_antiguedad) over ventana_6 as Visa_madelantopesos_sin_drif_slope_6
#     , regr_slope(Visa_madelantodolares_sin_drif, cliente_antiguedad) over ventana_6 as Visa_madelantodolares_sin_drif_slope_6
#     , regr_slope(Visa_fultimo_cierre, cliente_antiguedad) over ventana_6 as Visa_fultimo_cierre_slope_6
#     , regr_slope(Visa_mpagado_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mpagado_sin_drif_slope_6
#     , regr_slope(Visa_mpagospesos_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mpagospesos_sin_drif_slope_6
#     , regr_slope(Visa_mpagosdolares_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mpagosdolares_sin_drif_slope_6
#     , regr_slope(Visa_fechaalta, cliente_antiguedad) over ventana_6 as Visa_fechaalta_slope_6
#     , regr_slope(Visa_mconsumototal_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mconsumototal_sin_drif_slope_6
#     , regr_slope(Visa_cconsumos, cliente_antiguedad) over ventana_6 as Visa_cconsumos_slope_6
#     , regr_slope(Visa_cadelantosefectivo, cliente_antiguedad) over ventana_6 as Visa_cadelantosefectivo_slope_6
#     , regr_slope(Visa_mpagominimo_sin_drif, cliente_antiguedad) over ventana_6 as Visa_mpagominimo_sin_drif_slope_6
#
#     , min(active_quarter) over ventana_6 as active_quarter_min
#     , min(cliente_vip) over ventana_6 as cliente_vip_min
#     , min(internet) over ventana_6 as internet_min
#     , min(cliente_edad) over ventana_6 as cliente_edad_min
#     , min(cliente_antiguedad) over ventana_6 as cliente_antiguedad_min
#     , min(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_min
#     , min(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_min
#     , min(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_min
#     , min(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_min
#     , min(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_min
#     , min(cproductos) over ventana_6 as cproductos_min
#     , min(tcuentas) over ventana_6 as tcuentas_min
#     , min(ccuenta_corriente) over ventana_6 as ccuenta_corriente_min
#     , min(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_min
#     , min(mcuenta_corriente_sin_drif) over ventana_6 as mcuenta_corriente_sin_drif_min
#     , min(ccaja_ahorro) over ventana_6 as ccaja_ahorro_min
#     , min(mcaja_ahorro_sin_drif) over ventana_6 as mcaja_ahorro_sin_drif_min
#     , min(mcaja_ahorro_adicional_sin_drif) over ventana_6 as mcaja_ahorro_adicional_sin_drif_min
#     , min(mcaja_ahorro_dolares_sin_drif) over ventana_6 as mcaja_ahorro_dolares_sin_drif_min
#     , min(cdescubierto_preacordado) over ventana_6 as cdescubierto_preacordado_min
#     , min(mcuentas_saldo_sin_drif) over ventana_6 as mcuentas_saldo_sin_drif_min
#     , min(ctarjeta_debito) over ventana_6 as ctarjeta_debito_min
#     , min(ctarjeta_debito_transacciones) over ventana_6 as ctarjeta_debito_transacciones_min
#     , min(mautoservicio_sin_drif) over ventana_6 as mautoservicio_sin_drif_min
#     , min(ctarjeta_visa) over ventana_6 as ctarjeta_visa_min
#     , min(ctarjeta_visa_transacciones) over ventana_6 as ctarjeta_visa_transacciones_min
#     , min(mtarjeta_visa_consumo_sin_drif) over ventana_6 as mtarjeta_visa_consumo_sin_drif_min
#     , min(ctarjeta_master) over ventana_6 as ctarjeta_master_min
#     , min(ctarjeta_master_transacciones) over ventana_6 as ctarjeta_master_transacciones_min
#     , min(mtarjeta_master_consumo_sin_drif) over ventana_6 as mtarjeta_master_consumo_sin_drif_min
#     , min(cprestamos_personales) over ventana_6 as cprestamos_personales_min
#     , min(mprestamos_personales_sin_drif) over ventana_6 as mprestamos_personales_sin_drif_min
#     , min(cprestamos_prendarios) over ventana_6 as cprestamos_prendarios_min
#     , min(mprestamos_prendarios_sin_drif) over ventana_6 as mprestamos_prendarios_sin_drif_min
#     , min(cprestamos_hipotecarios) over ventana_6 as cprestamos_hipotecarios_min
#     , min(mprestamos_hipotecarios_sin_drif) over ventana_6 as mprestamos_hipotecarios_sin_drif_min
#     , min(cplazo_fijo) over ventana_6 as cplazo_fijo_min
#     , min(mplazo_fijo_dolares_sin_drif) over ventana_6 as mplazo_fijo_dolares_sin_drif_min
#     , min(mplazo_fijo_pesos_sin_drif) over ventana_6 as mplazo_fijo_pesos_sin_drif_min
#     , min(cinversion1) over ventana_6 as cinversion1_min
#     , min(minversion1_pesos_sin_drif) over ventana_6 as minversion1_pesos_sin_drif_min
#     , min(minversion1_dolares_sin_drif) over ventana_6 as minversion1_dolares_sin_drif_min
#     , min(cinversion2) over ventana_6 as cinversion2_min
#     , min(minversion2_sin_drif) over ventana_6 as minversion2_sin_drif_min
#     , min(cseguro_vida) over ventana_6 as cseguro_vida_min
#     , min(cseguro_auto) over ventana_6 as cseguro_auto_min
#     , min(cseguro_vivienda) over ventana_6 as cseguro_vivienda_min
#     , min(cseguro_accidentes_personales) over ventana_6 as cseguro_accidentes_personales_min
#     , min(ccaja_seguridad) over ventana_6 as ccaja_seguridad_min
#     , min(cpayroll_trx) over ventana_6 as cpayroll_trx_min
#     , min(mpayroll_sin_drif) over ventana_6 as mpayroll_sin_drif_min
#     , min(mpayroll2_sin_drif) over ventana_6 as mpayroll2_sin_drif_min
#     , min(cpayroll2_trx) over ventana_6 as cpayroll2_trx_min
#     , min(ccuenta_debitos_automaticos) over ventana_6 as ccuenta_debitos_automaticos_min
#     , min(mcuenta_debitos_automaticos_sin_drif) over ventana_6 as mcuenta_debitos_automaticos_sin_drif_min
#     , min(ctarjeta_visa_debitos_automaticos) over ventana_6 as ctarjeta_visa_debitos_automaticos_min
#     , min(mttarjeta_visa_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_visa_debitos_automaticos_sin_drif_min
#     , min(ctarjeta_master_debitos_automaticos) over ventana_6 as ctarjeta_master_debitos_automaticos_min
#     , min(mttarjeta_master_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_master_debitos_automaticos_sin_drif_min
#     , min(cpagodeservicios) over ventana_6 as cpagodeservicios_min
#     , min(mpagodeservicios_sin_drif) over ventana_6 as mpagodeservicios_sin_drif_min
#     , min(cpagomiscuentas) over ventana_6 as cpagomiscuentas_min
#     , min(mpagomiscuentas_sin_drif) over ventana_6 as mpagomiscuentas_sin_drif_min
#     , min(ccajeros_propios_descuentos) over ventana_6 as ccajeros_propios_descuentos_min
#     , min(mcajeros_propios_descuentos_sin_drif) over ventana_6 as mcajeros_propios_descuentos_sin_drif_min
#     , min(ctarjeta_visa_descuentos) over ventana_6 as ctarjeta_visa_descuentos_min
#     , min(mtarjeta_visa_descuentos_sin_drif) over ventana_6 as mtarjeta_visa_descuentos_sin_drif_min
#     , min(ctarjeta_master_descuentos) over ventana_6 as ctarjeta_master_descuentos_min
#     , min(mtarjeta_master_descuentos_sin_drif) over ventana_6 as mtarjeta_master_descuentos_sin_drif_min
#     , min(ccomisiones_mantenimiento) over ventana_6 as ccomisiones_mantenimiento_min
#     , min(mcomisiones_mantenimiento_sin_drif) over ventana_6 as mcomisiones_mantenimiento_sin_drif_min
#     , min(ccomisiones_otras) over ventana_6 as ccomisiones_otras_min
#     , min(mcomisiones_otras_sin_drif) over ventana_6 as mcomisiones_otras_sin_drif_min
#     , min(cforex) over ventana_6 as cforex_min
#     , min(cforex_buy) over ventana_6 as cforex_buy_min
#     , min(mforex_buy_sin_drif) over ventana_6 as mforex_buy_sin_drif_min
#     , min(cforex_sell) over ventana_6 as cforex_sell_min
#     , min(mforex_sell_sin_drif) over ventana_6 as mforex_sell_sin_drif_min
#     , min(ctransferencias_recibidas) over ventana_6 as ctransferencias_recibidas_min
#     , min(mtransferencias_recibidas_sin_drif) over ventana_6 as mtransferencias_recibidas_sin_drif_min
#     , min(ctransferencias_emitidas) over ventana_6 as ctransferencias_emitidas_min
#     , min(mtransferencias_emitidas_sin_drif) over ventana_6 as mtransferencias_emitidas_sin_drif_min
#     , min(cextraccion_autoservicio) over ventana_6 as cextraccion_autoservicio_min
#     , min(mextraccion_autoservicio_sin_drif) over ventana_6 as mextraccion_autoservicio_sin_drif_min
#     , min(ccheques_depositados) over ventana_6 as ccheques_depositados_min
#     , min(mcheques_depositados_sin_drif) over ventana_6 as mcheques_depositados_sin_drif_min
#     , min(ccheques_emitidos) over ventana_6 as ccheques_emitidos_min
#     , min(mcheques_emitidos_sin_drif) over ventana_6 as mcheques_emitidos_sin_drif_min
#     , min(ccheques_depositados_rechazados) over ventana_6 as ccheques_depositados_rechazados_min
#     , min(mcheques_depositados_rechazados_sin_drif) over ventana_6 as mcheques_depositados_rechazados_sin_drif_min
#     , min(ccheques_emitidos_rechazados) over ventana_6 as ccheques_emitidos_rechazados_min
#     , min(mcheques_emitidos_rechazados_sin_drif) over ventana_6 as mcheques_emitidos_rechazados_sin_drif_min
#     , min(tcallcenter) over ventana_6 as tcallcenter_min
#     , min(ccallcenter_transacciones) over ventana_6 as ccallcenter_transacciones_min
#     , min(thomebanking) over ventana_6 as thomebanking_min
#     , min(chomebanking_transacciones) over ventana_6 as chomebanking_transacciones_min
#     , min(ccajas_transacciones) over ventana_6 as ccajas_transacciones_min
#     , min(ccajas_consultas) over ventana_6 as ccajas_consultas_min
#     , min(ccajas_depositos) over ventana_6 as ccajas_depositos_min
#     , min(ccajas_extracciones) over ventana_6 as ccajas_extracciones_min
#     , min(ccajas_otras) over ventana_6 as ccajas_otras_min
#     , min(catm_trx) over ventana_6 as catm_trx_min
#     , min(matm_sin_drif) over ventana_6 as matm_sin_drif_min
#     , min(catm_trx_other) over ventana_6 as catm_trx_other_min
#     , min(matm_other_sin_drif) over ventana_6 as matm_other_sin_drif_min
#     , min(ctrx_quarter) over ventana_6 as ctrx_quarter_min
#     , min(Master_delinquency) over ventana_6 as Master_delinquency_min
#     , min(Master_status) over ventana_6 as Master_status_min
#     , min(Master_mfinanciacion_limite_sin_drif) over ventana_6 as Master_mfinanciacion_limite_sin_drif_min
#     , min(Master_Fvencimiento) over ventana_6 as Master_Fvencimiento_min
#     , min(Master_Finiciomora) over ventana_6 as Master_Finiciomora_min
#     , min(Master_msaldototal_sin_drif) over ventana_6 as Master_msaldototal_sin_drif_min
#     , min(Master_msaldopesos_sin_drif) over ventana_6 as Master_msaldopesos_sin_drif_min
#     , min(Master_msaldodolares_sin_drif) over ventana_6 as Master_msaldodolares_sin_drif_min
#     , min(Master_mconsumospesos_sin_drif) over ventana_6 as Master_mconsumospesos_sin_drif_min
#     , min(Master_mconsumosdolares_sin_drif) over ventana_6 as Master_mconsumosdolares_sin_drif_min
#     , min(Master_mlimitecompra_sin_drif) over ventana_6 as Master_mlimitecompra_sin_drif_min
#     , min(Master_madelantopesos_sin_drif) over ventana_6 as Master_madelantopesos_sin_drif_min
#     , min(Master_madelantodolares_sin_drif) over ventana_6 as Master_madelantodolares_sin_drif_min
#     , min(Master_fultimo_cierre) over ventana_6 as Master_fultimo_cierre_min
#     , min(Master_mpagado_sin_drif) over ventana_6 as Master_mpagado_sin_drif_min
#     , min(Master_mpagospesos_sin_drif) over ventana_6 as Master_mpagospesos_sin_drif_min
#     , min(Master_mpagosdolares_sin_drif) over ventana_6 as Master_mpagosdolares_sin_drif_min
#     , min(Master_fechaalta) over ventana_6 as Master_fechaalta_min
#     , min(Master_mconsumototal_sin_drif) over ventana_6 as Master_mconsumototal_sin_drif_min
#     , min(Master_cconsumos_sin_drif) over ventana_6 as Master_cconsumos_sin_drif_min
#     , min(Master_cadelantosefectivo) over ventana_6 as Master_cadelantosefectivo_min
#     , min(Master_mpagominimo_sin_drif) over ventana_6 as Master_mpagominimo_sin_drif_min
#     , min(Visa_delinquency) over ventana_6 as Visa_delinquency_min
#     , min(Visa_status) over ventana_6 as Visa_status_min
#     , min(Visa_mfinanciacion_limite_sin_drif) over ventana_6 as Visa_mfinanciacion_limite_sin_drif_min
#     , min(Visa_Fvencimiento) over ventana_6 as Visa_Fvencimiento_min
#     , min(Visa_Finiciomora) over ventana_6 as Visa_Finiciomora_min
#     , min(Visa_msaldototal_sin_drif) over ventana_6 as Visa_msaldototal_sin_drif_min
#     , min(Visa_msaldopesos_sin_drif) over ventana_6 as Visa_msaldopesos_sin_drif_min
#     , min(Visa_msaldodolares_sin_drif) over ventana_6 as Visa_msaldodolares_sin_drif_min
#     , min(Visa_mconsumospesos_sin_drif) over ventana_6 as Visa_mconsumospesos_sin_drif_min
#     , min(Visa_mconsumosdolares_sin_drif) over ventana_6 as Visa_mconsumosdolares_sin_drif_min
#     , min(Visa_mlimitecompra_sin_drif) over ventana_6 as Visa_mlimitecompra_sin_drif_min
#     , min(Visa_madelantopesos_sin_drif) over ventana_6 as Visa_madelantopesos_sin_drif_min
#     , min(Visa_madelantodolares_sin_drif) over ventana_6 as Visa_madelantodolares_sin_drif_min
#     , min(Visa_fultimo_cierre) over ventana_6 as Visa_fultimo_cierre_min
#     , min(Visa_mpagado_sin_drif) over ventana_6 as Visa_mpagado_sin_drif_min
#     , min(Visa_mpagospesos_sin_drif) over ventana_6 as Visa_mpagospesos_sin_drif_min
#     , min(Visa_mpagosdolares_sin_drif) over ventana_6 as Visa_mpagosdolares_sin_drif_min
#     , min(Visa_fechaalta) over ventana_6 as Visa_fechaalta_min
#     , min(Visa_mconsumototal_sin_drif) over ventana_6 as Visa_mconsumototal_sin_drif_min
#     , min(Visa_cconsumos) over ventana_6 as Visa_cconsumos_min
#     , min(Visa_cadelantosefectivo) over ventana_6 as Visa_cadelantosefectivo_min
#     , min(Visa_mpagominimo_sin_drif) over ventana_6 as Visa_mpagominimo_sin_drif_min
#
#     , max(active_quarter) over ventana_6 as active_quarter_max
#     , max(cliente_vip) over ventana_6 as cliente_vip_max
#     , max(internet) over ventana_6 as internet_max
#     , max(cliente_edad) over ventana_6 as cliente_edad_max
#     , max(cliente_antiguedad) over ventana_6 as cliente_antiguedad_max
#     , max(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_max
#     , max(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_max
#     , max(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_max
#     , max(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_max
#     , max(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_max
#     , max(cproductos) over ventana_6 as cproductos_max
#     , max(tcuentas) over ventana_6 as tcuentas_max
#     , max(ccuenta_corriente) over ventana_6 as ccuenta_corriente_max
#     , max(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_max
#     , max(mcuenta_corriente_sin_drif) over ventana_6 as mcuenta_corriente_sin_drif_max
#     , max(ccaja_ahorro) over ventana_6 as ccaja_ahorro_max
#     , max(mcaja_ahorro_sin_drif) over ventana_6 as mcaja_ahorro_sin_drif_max
#     , max(mcaja_ahorro_adicional_sin_drif) over ventana_6 as mcaja_ahorro_adicional_sin_drif_max
#     , max(mcaja_ahorro_dolares_sin_drif) over ventana_6 as mcaja_ahorro_dolares_sin_drif_max
#     , max(cdescubierto_preacordado) over ventana_6 as cdescubierto_preacordado_max
#     , max(mcuentas_saldo_sin_drif) over ventana_6 as mcuentas_saldo_sin_drif_max
#     , max(ctarjeta_debito) over ventana_6 as ctarjeta_debito_max
#     , max(ctarjeta_debito_transacciones) over ventana_6 as ctarjeta_debito_transacciones_max
#     , max(mautoservicio_sin_drif) over ventana_6 as mautoservicio_sin_drif_max
#     , max(ctarjeta_visa) over ventana_6 as ctarjeta_visa_max
#     , max(ctarjeta_visa_transacciones) over ventana_6 as ctarjeta_visa_transacciones_max
#     , max(mtarjeta_visa_consumo_sin_drif) over ventana_6 as mtarjeta_visa_consumo_sin_drif_max
#     , max(ctarjeta_master) over ventana_6 as ctarjeta_master_max
#     , max(ctarjeta_master_transacciones) over ventana_6 as ctarjeta_master_transacciones_max
#     , max(mtarjeta_master_consumo_sin_drif) over ventana_6 as mtarjeta_master_consumo_sin_drif_max
#     , max(cprestamos_personales) over ventana_6 as cprestamos_personales_max
#     , max(mprestamos_personales_sin_drif) over ventana_6 as mprestamos_personales_sin_drif_max
#     , max(cprestamos_prendarios) over ventana_6 as cprestamos_prendarios_max
#     , max(mprestamos_prendarios_sin_drif) over ventana_6 as mprestamos_prendarios_sin_drif_max
#     , max(cprestamos_hipotecarios) over ventana_6 as cprestamos_hipotecarios_max
#     , max(mprestamos_hipotecarios_sin_drif) over ventana_6 as mprestamos_hipotecarios_sin_drif_max
#     , max(cplazo_fijo) over ventana_6 as cplazo_fijo_max
#     , max(mplazo_fijo_dolares_sin_drif) over ventana_6 as mplazo_fijo_dolares_sin_drif_max
#     , max(mplazo_fijo_pesos_sin_drif) over ventana_6 as mplazo_fijo_pesos_sin_drif_max
#     , max(cinversion1) over ventana_6 as cinversion1_max
#     , max(minversion1_pesos_sin_drif) over ventana_6 as minversion1_pesos_sin_drif_max
#     , max(minversion1_dolares_sin_drif) over ventana_6 as minversion1_dolares_sin_drif_max
#     , max(cinversion2) over ventana_6 as cinversion2_max
#     , max(minversion2_sin_drif) over ventana_6 as minversion2_sin_drif_max
#     , max(cseguro_vida) over ventana_6 as cseguro_vida_max
#     , max(cseguro_auto) over ventana_6 as cseguro_auto_max
#     , max(cseguro_vivienda) over ventana_6 as cseguro_vivienda_max
#     , max(cseguro_accidentes_personales) over ventana_6 as cseguro_accidentes_personales_max
#     , max(ccaja_seguridad) over ventana_6 as ccaja_seguridad_max
#     , max(cpayroll_trx) over ventana_6 as cpayroll_trx_max
#     , max(mpayroll_sin_drif) over ventana_6 as mpayroll_sin_drif_max
#     , max(mpayroll2_sin_drif) over ventana_6 as mpayroll2_sin_drif_max
#     , max(cpayroll2_trx) over ventana_6 as cpayroll2_trx_max
#     , max(ccuenta_debitos_automaticos) over ventana_6 as ccuenta_debitos_automaticos_max
#     , max(mcuenta_debitos_automaticos_sin_drif) over ventana_6 as mcuenta_debitos_automaticos_sin_drif_max
#     , max(ctarjeta_visa_debitos_automaticos) over ventana_6 as ctarjeta_visa_debitos_automaticos_max
#     , max(mttarjeta_visa_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_visa_debitos_automaticos_sin_drif_max
#     , max(ctarjeta_master_debitos_automaticos) over ventana_6 as ctarjeta_master_debitos_automaticos_max
#     , max(mttarjeta_master_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_master_debitos_automaticos_sin_drif_max
#     , max(cpagodeservicios) over ventana_6 as cpagodeservicios_max
#     , max(mpagodeservicios_sin_drif) over ventana_6 as mpagodeservicios_sin_drif_max
#     , max(cpagomiscuentas) over ventana_6 as cpagomiscuentas_max
#     , max(mpagomiscuentas_sin_drif) over ventana_6 as mpagomiscuentas_sin_drif_max
#     , max(ccajeros_propios_descuentos) over ventana_6 as ccajeros_propios_descuentos_max
#     , max(mcajeros_propios_descuentos_sin_drif) over ventana_6 as mcajeros_propios_descuentos_sin_drif_max
#     , max(ctarjeta_visa_descuentos) over ventana_6 as ctarjeta_visa_descuentos_max
#     , max(mtarjeta_visa_descuentos_sin_drif) over ventana_6 as mtarjeta_visa_descuentos_sin_drif_max
#     , max(ctarjeta_master_descuentos) over ventana_6 as ctarjeta_master_descuentos_max
#     , max(mtarjeta_master_descuentos_sin_drif) over ventana_6 as mtarjeta_master_descuentos_sin_drif_max
#     , max(ccomisiones_mantenimiento) over ventana_6 as ccomisiones_mantenimiento_max
#     , max(mcomisiones_mantenimiento_sin_drif) over ventana_6 as mcomisiones_mantenimiento_sin_drif_max
#     , max(ccomisiones_otras) over ventana_6 as ccomisiones_otras_max
#     , max(mcomisiones_otras_sin_drif) over ventana_6 as mcomisiones_otras_sin_drif_max
#     , max(cforex) over ventana_6 as cforex_max
#     , max(cforex_buy) over ventana_6 as cforex_buy_max
#     , max(mforex_buy_sin_drif) over ventana_6 as mforex_buy_sin_drif_max
#     , max(cforex_sell) over ventana_6 as cforex_sell_max
#     , max(mforex_sell_sin_drif) over ventana_6 as mforex_sell_sin_drif_max
#     , max(ctransferencias_recibidas) over ventana_6 as ctransferencias_recibidas_max
#     , max(mtransferencias_recibidas_sin_drif) over ventana_6 as mtransferencias_recibidas_sin_drif_max
#     , max(ctransferencias_emitidas) over ventana_6 as ctransferencias_emitidas_max
#     , max(mtransferencias_emitidas_sin_drif) over ventana_6 as mtransferencias_emitidas_sin_drif_max
#     , max(cextraccion_autoservicio) over ventana_6 as cextraccion_autoservicio_max
#     , max(mextraccion_autoservicio_sin_drif) over ventana_6 as mextraccion_autoservicio_sin_drif_max
#     , max(ccheques_depositados) over ventana_6 as ccheques_depositados_max
#     , max(mcheques_depositados_sin_drif) over ventana_6 as mcheques_depositados_sin_drif_max
#     , max(ccheques_emitidos) over ventana_6 as ccheques_emitidos_max
#     , max(mcheques_emitidos_sin_drif) over ventana_6 as mcheques_emitidos_sin_drif_max
#     , max(ccheques_depositados_rechazados) over ventana_6 as ccheques_depositados_rechazados_max
#     , max(mcheques_depositados_rechazados_sin_drif) over ventana_6 as mcheques_depositados_rechazados_sin_drif_max
#     , max(ccheques_emitidos_rechazados) over ventana_6 as ccheques_emitidos_rechazados_max
#     , max(mcheques_emitidos_rechazados_sin_drif) over ventana_6 as mcheques_emitidos_rechazados_sin_drif_max
#     , max(tcallcenter) over ventana_6 as tcallcenter_max
#     , max(ccallcenter_transacciones) over ventana_6 as ccallcenter_transacciones_max
#     , max(thomebanking) over ventana_6 as thomebanking_max
#     , max(chomebanking_transacciones) over ventana_6 as chomebanking_transacciones_max
#     , max(ccajas_transacciones) over ventana_6 as ccajas_transacciones_max
#     , max(ccajas_consultas) over ventana_6 as ccajas_consultas_max
#     , max(ccajas_depositos) over ventana_6 as ccajas_depositos_max
#     , max(ccajas_extracciones) over ventana_6 as ccajas_extracciones_max
#     , max(ccajas_otras) over ventana_6 as ccajas_otras_max
#     , max(catm_trx) over ventana_6 as catm_trx_max
#     , max(matm_sin_drif) over ventana_6 as matm_sin_drif_max
#     , max(catm_trx_other) over ventana_6 as catm_trx_other_max
#     , max(matm_other_sin_drif) over ventana_6 as matm_other_sin_drif_max
#     , max(ctrx_quarter) over ventana_6 as ctrx_quarter_max
#     , max(Master_delinquency) over ventana_6 as Master_delinquency_max
#     , max(Master_status) over ventana_6 as Master_status_max
#     , max(Master_mfinanciacion_limite_sin_drif) over ventana_6 as Master_mfinanciacion_limite_sin_drif_max
#     , max(Master_Fvencimiento) over ventana_6 as Master_Fvencimiento_max
#     , max(Master_Finiciomora) over ventana_6 as Master_Finiciomora_max
#     , max(Master_msaldototal_sin_drif) over ventana_6 as Master_msaldototal_sin_drif_max
#     , max(Master_msaldopesos_sin_drif) over ventana_6 as Master_msaldopesos_sin_drif_max
#     , max(Master_msaldodolares_sin_drif) over ventana_6 as Master_msaldodolares_sin_drif_max
#     , max(Master_mconsumospesos_sin_drif) over ventana_6 as Master_mconsumospesos_sin_drif_max
#     , max(Master_mconsumosdolares_sin_drif) over ventana_6 as Master_mconsumosdolares_sin_drif_max
#     , max(Master_mlimitecompra_sin_drif) over ventana_6 as Master_mlimitecompra_sin_drif_max
#     , max(Master_madelantopesos_sin_drif) over ventana_6 as Master_madelantopesos_sin_drif_max
#     , max(Master_madelantodolares_sin_drif) over ventana_6 as Master_madelantodolares_sin_drif_max
#     , max(Master_fultimo_cierre) over ventana_6 as Master_fultimo_cierre_max
#     , max(Master_mpagado_sin_drif) over ventana_6 as Master_mpagado_sin_drif_max
#     , max(Master_mpagospesos_sin_drif) over ventana_6 as Master_mpagospesos_sin_drif_max
#     , max(Master_mpagosdolares_sin_drif) over ventana_6 as Master_mpagosdolares_sin_drif_max
#     , max(Master_fechaalta) over ventana_6 as Master_fechaalta_max
#     , max(Master_mconsumototal_sin_drif) over ventana_6 as Master_mconsumototal_sin_drif_max
#     , max(Master_cconsumos_sin_drif) over ventana_6 as Master_cconsumos_sin_drif_max
#     , max(Master_cadelantosefectivo) over ventana_6 as Master_cadelantosefectivo_max
#     , max(Master_mpagominimo_sin_drif) over ventana_6 as Master_mpagominimo_sin_drif_max
#     , max(Visa_delinquency) over ventana_6 as Visa_delinquency_max
#     , max(Visa_status) over ventana_6 as Visa_status_max
#     , max(Visa_mfinanciacion_limite_sin_drif) over ventana_6 as Visa_mfinanciacion_limite_sin_drif_max
#     , max(Visa_Fvencimiento) over ventana_6 as Visa_Fvencimiento_max
#     , max(Visa_Finiciomora) over ventana_6 as Visa_Finiciomora_max
#     , max(Visa_msaldototal_sin_drif) over ventana_6 as Visa_msaldototal_sin_drif_max
#     , max(Visa_msaldopesos_sin_drif) over ventana_6 as Visa_msaldopesos_sin_drif_max
#     , max(Visa_msaldodolares_sin_drif) over ventana_6 as Visa_msaldodolares_sin_drif_max
#     , max(Visa_mconsumospesos_sin_drif) over ventana_6 as Visa_mconsumospesos_sin_drif_max
#     , max(Visa_mconsumosdolares_sin_drif) over ventana_6 as Visa_mconsumosdolares_sin_drif_max
#     , max(Visa_mlimitecompra_sin_drif) over ventana_6 as Visa_mlimitecompra_sin_drif_max
#     , max(Visa_madelantopesos_sin_drif) over ventana_6 as Visa_madelantopesos_sin_drif_max
#     , max(Visa_madelantodolares_sin_drif) over ventana_6 as Visa_madelantodolares_sin_drif_max
#     , max(Visa_fultimo_cierre) over ventana_6 as Visa_fultimo_cierre_max
#     , max(Visa_mpagado_sin_drif) over ventana_6 as Visa_mpagado_sin_drif_max
#     , max(Visa_mpagospesos_sin_drif) over ventana_6 as Visa_mpagospesos_sin_drif_max
#     , max(Visa_mpagosdolares_sin_drif) over ventana_6 as Visa_mpagosdolares_sin_drif_max
#     , max(Visa_fechaalta) over ventana_6 as Visa_fechaalta_max
#     , max(Visa_mconsumototal_sin_drif) over ventana_6 as Visa_mconsumototal_sin_drif_max
#     , max(Visa_cconsumos) over ventana_6 as Visa_cconsumos_max
#     , max(Visa_cadelantosefectivo) over ventana_6 as Visa_cadelantosefectivo_max
#     , max(Visa_mpagominimo_sin_drif) over ventana_6 as Visa_mpagominimo_sin_drif_max
#
#     , avg(active_quarter) over ventana_6 as active_quarter_avg
#     , avg(cliente_vip) over ventana_6 as cliente_vip_avg
#     , avg(internet) over ventana_6 as internet_avg
#     , avg(cliente_edad) over ventana_6 as cliente_edad_avg
#     , avg(cliente_antiguedad) over ventana_6 as cliente_antiguedad_avg
#     , avg(mrentabilidad_sin_drif) over ventana_6 as mrentabilidad_sin_drif_avg
#     , avg(mrentabilidad_annual_sin_drif) over ventana_6 as mrentabilidad_annual_sin_drif_avg
#     , avg(mcomisiones_sin_drif) over ventana_6 as mcomisiones_sin_drif_avg
#     , avg(mactivos_margen_sin_drif) over ventana_6 as mactivos_margen_sin_drif_avg
#     , avg(mpasivos_margen_sin_drif) over ventana_6 as mpasivos_margen_sin_drif_avg
#     , avg(cproductos) over ventana_6 as cproductos_avg
#     , avg(tcuentas) over ventana_6 as tcuentas_avg
#     , avg(ccuenta_corriente) over ventana_6 as ccuenta_corriente_avg
#     , avg(mcuenta_corriente_adicional_sin_drif) over ventana_6 as mcuenta_corriente_adicional_sin_drif_avg
#     , avg(mcuenta_corriente_sin_drif) over ventana_6 as mcuenta_corriente_sin_drif_avg
#     , avg(ccaja_ahorro) over ventana_6 as ccaja_ahorro_avg
#     , avg(mcaja_ahorro_sin_drif) over ventana_6 as mcaja_ahorro_sin_drif_avg
#     , avg(mcaja_ahorro_adicional_sin_drif) over ventana_6 as mcaja_ahorro_adicional_sin_drif_avg
#     , avg(mcaja_ahorro_dolares_sin_drif) over ventana_6 as mcaja_ahorro_dolares_sin_drif_avg
#     , avg(cdescubierto_preacordado) over ventana_6 as cdescubierto_preacordado_avg
#     , avg(mcuentas_saldo_sin_drif) over ventana_6 as mcuentas_saldo_sin_drif_avg
#     , avg(ctarjeta_debito) over ventana_6 as ctarjeta_debito_avg
#     , avg(ctarjeta_debito_transacciones) over ventana_6 as ctarjeta_debito_transacciones_avg
#     , avg(mautoservicio_sin_drif) over ventana_6 as mautoservicio_sin_drif_avg
#     , avg(ctarjeta_visa) over ventana_6 as ctarjeta_visa_avg
#     , avg(ctarjeta_visa_transacciones) over ventana_6 as ctarjeta_visa_transacciones_avg
#     , avg(mtarjeta_visa_consumo_sin_drif) over ventana_6 as mtarjeta_visa_consumo_sin_drif_avg
#     , avg(ctarjeta_master) over ventana_6 as ctarjeta_master_avg
#     , avg(ctarjeta_master_transacciones) over ventana_6 as ctarjeta_master_transacciones_avg
#     , avg(mtarjeta_master_consumo_sin_drif) over ventana_6 as mtarjeta_master_consumo_sin_drif_avg
#     , avg(cprestamos_personales) over ventana_6 as cprestamos_personales_avg
#     , avg(mprestamos_personales_sin_drif) over ventana_6 as mprestamos_personales_sin_drif_avg
#     , avg(cprestamos_prendarios) over ventana_6 as cprestamos_prendarios_avg
#     , avg(mprestamos_prendarios_sin_drif) over ventana_6 as mprestamos_prendarios_sin_drif_avg
#     , avg(cprestamos_hipotecarios) over ventana_6 as cprestamos_hipotecarios_avg
#     , avg(mprestamos_hipotecarios_sin_drif) over ventana_6 as mprestamos_hipotecarios_sin_drif_avg
#     , avg(cplazo_fijo) over ventana_6 as cplazo_fijo_avg
#     , avg(mplazo_fijo_dolares_sin_drif) over ventana_6 as mplazo_fijo_dolares_sin_drif_avg
#     , avg(mplazo_fijo_pesos_sin_drif) over ventana_6 as mplazo_fijo_pesos_sin_drif_avg
#     , avg(cinversion1) over ventana_6 as cinversion1_avg
#     , avg(minversion1_pesos_sin_drif) over ventana_6 as minversion1_pesos_sin_drif_avg
#     , avg(minversion1_dolares_sin_drif) over ventana_6 as minversion1_dolares_sin_drif_avg
#     , avg(cinversion2) over ventana_6 as cinversion2_avg
#     , avg(minversion2_sin_drif) over ventana_6 as minversion2_sin_drif_avg
#     , avg(cseguro_vida) over ventana_6 as cseguro_vida_avg
#     , avg(cseguro_auto) over ventana_6 as cseguro_auto_avg
#     , avg(cseguro_vivienda) over ventana_6 as cseguro_vivienda_avg
#     , avg(cseguro_accidentes_personales) over ventana_6 as cseguro_accidentes_personales_avg
#     , avg(ccaja_seguridad) over ventana_6 as ccaja_seguridad_avg
#     , avg(cpayroll_trx) over ventana_6 as cpayroll_trx_avg
#     , avg(mpayroll_sin_drif) over ventana_6 as mpayroll_sin_drif_avg
#     , avg(mpayroll2_sin_drif) over ventana_6 as mpayroll2_sin_drif_avg
#     , avg(cpayroll2_trx) over ventana_6 as cpayroll2_trx_avg
#     , avg(ccuenta_debitos_automaticos) over ventana_6 as ccuenta_debitos_automaticos_avg
#     , avg(mcuenta_debitos_automaticos_sin_drif) over ventana_6 as mcuenta_debitos_automaticos_sin_drif_avg
#     , avg(ctarjeta_visa_debitos_automaticos) over ventana_6 as ctarjeta_visa_debitos_automaticos_avg
#     , avg(mttarjeta_visa_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_visa_debitos_automaticos_sin_drif_avg
#     , avg(ctarjeta_master_debitos_automaticos) over ventana_6 as ctarjeta_master_debitos_automaticos_avg
#     , avg(mttarjeta_master_debitos_automaticos_sin_drif) over ventana_6 as mttarjeta_master_debitos_automaticos_sin_drif_avg
#     , avg(cpagodeservicios) over ventana_6 as cpagodeservicios_avg
#     , avg(mpagodeservicios_sin_drif) over ventana_6 as mpagodeservicios_sin_drif_avg
#     , avg(cpagomiscuentas) over ventana_6 as cpagomiscuentas_avg
#     , avg(mpagomiscuentas_sin_drif) over ventana_6 as mpagomiscuentas_sin_drif_avg
#     , avg(ccajeros_propios_descuentos) over ventana_6 as ccajeros_propios_descuentos_avg
#     , avg(mcajeros_propios_descuentos_sin_drif) over ventana_6 as mcajeros_propios_descuentos_sin_drif_avg
#     , avg(ctarjeta_visa_descuentos) over ventana_6 as ctarjeta_visa_descuentos_avg
#     , avg(mtarjeta_visa_descuentos_sin_drif) over ventana_6 as mtarjeta_visa_descuentos_sin_drif_avg
#     , avg(ctarjeta_master_descuentos) over ventana_6 as ctarjeta_master_descuentos_avg
#     , avg(mtarjeta_master_descuentos_sin_drif) over ventana_6 as mtarjeta_master_descuentos_sin_drif_avg
#     , avg(ccomisiones_mantenimiento) over ventana_6 as ccomisiones_mantenimiento_avg
#     , avg(mcomisiones_mantenimiento_sin_drif) over ventana_6 as mcomisiones_mantenimiento_sin_drif_avg
#     , avg(ccomisiones_otras) over ventana_6 as ccomisiones_otras_avg
#     , avg(mcomisiones_otras_sin_drif) over ventana_6 as mcomisiones_otras_sin_drif_avg
#     , avg(cforex) over ventana_6 as cforex_avg
#     , avg(cforex_buy) over ventana_6 as cforex_buy_avg
#     , avg(mforex_buy_sin_drif) over ventana_6 as mforex_buy_sin_drif_avg
#     , avg(cforex_sell) over ventana_6 as cforex_sell_avg
#     , avg(mforex_sell_sin_drif) over ventana_6 as mforex_sell_sin_drif_avg
#     , avg(ctransferencias_recibidas) over ventana_6 as ctransferencias_recibidas_avg
#     , avg(mtransferencias_recibidas_sin_drif) over ventana_6 as mtransferencias_recibidas_sin_drif_avg
#     , avg(ctransferencias_emitidas) over ventana_6 as ctransferencias_emitidas_avg
#     , avg(mtransferencias_emitidas_sin_drif) over ventana_6 as mtransferencias_emitidas_sin_drif_avg
#     , avg(cextraccion_autoservicio) over ventana_6 as cextraccion_autoservicio_avg
#     , avg(mextraccion_autoservicio_sin_drif) over ventana_6 as mextraccion_autoservicio_sin_drif_avg
#     , avg(ccheques_depositados) over ventana_6 as ccheques_depositados_avg
#     , avg(mcheques_depositados_sin_drif) over ventana_6 as mcheques_depositados_sin_drif_avg
#     , avg(ccheques_emitidos) over ventana_6 as ccheques_emitidos_avg
#     , avg(mcheques_emitidos_sin_drif) over ventana_6 as mcheques_emitidos_sin_drif_avg
#     , avg(ccheques_depositados_rechazados) over ventana_6 as ccheques_depositados_rechazados_avg
#     , avg(mcheques_depositados_rechazados_sin_drif) over ventana_6 as mcheques_depositados_rechazados_sin_drif_avg
#     , avg(ccheques_emitidos_rechazados) over ventana_6 as ccheques_emitidos_rechazados_avg
#     , avg(mcheques_emitidos_rechazados_sin_drif) over ventana_6 as mcheques_emitidos_rechazados_sin_drif_avg
#     , avg(tcallcenter) over ventana_6 as tcallcenter_avg
#     , avg(ccallcenter_transacciones) over ventana_6 as ccallcenter_transacciones_avg
#     , avg(thomebanking) over ventana_6 as thomebanking_avg
#     , avg(chomebanking_transacciones) over ventana_6 as chomebanking_transacciones_avg
#     , avg(ccajas_transacciones) over ventana_6 as ccajas_transacciones_avg
#     , avg(ccajas_consultas) over ventana_6 as ccajas_consultas_avg
#     , avg(ccajas_depositos) over ventana_6 as ccajas_depositos_avg
#     , avg(ccajas_extracciones) over ventana_6 as ccajas_extracciones_avg
#     , avg(ccajas_otras) over ventana_6 as ccajas_otras_avg
#     , avg(catm_trx) over ventana_6 as catm_trx_avg
#     , avg(matm_sin_drif) over ventana_6 as matm_sin_drif_avg
#     , avg(catm_trx_other) over ventana_6 as catm_trx_other_avg
#     , avg(matm_other_sin_drif) over ventana_6 as matm_other_sin_drif_avg
#     , avg(ctrx_quarter) over ventana_6 as ctrx_quarter_avg
#     , avg(Master_delinquency) over ventana_6 as Master_delinquency_avg
#     , avg(Master_status) over ventana_6 as Master_status_avg
#     , avg(Master_mfinanciacion_limite_sin_drif) over ventana_6 as Master_mfinanciacion_limite_sin_drif_avg
#     , avg(Master_Fvencimiento) over ventana_6 as Master_Fvencimiento_avg
#     , avg(Master_Finiciomora) over ventana_6 as Master_Finiciomora_avg
#     , avg(Master_msaldototal_sin_drif) over ventana_6 as Master_msaldototal_sin_drif_avg
#     , avg(Master_msaldopesos_sin_drif) over ventana_6 as Master_msaldopesos_sin_drif_avg
#     , avg(Master_msaldodolares_sin_drif) over ventana_6 as Master_msaldodolares_sin_drif_avg
#     , avg(Master_mconsumospesos_sin_drif) over ventana_6 as Master_mconsumospesos_sin_drif_avg
#     , avg(Master_mconsumosdolares_sin_drif) over ventana_6 as Master_mconsumosdolares_sin_drif_avg
#     , avg(Master_mlimitecompra_sin_drif) over ventana_6 as Master_mlimitecompra_sin_drif_avg
#     , avg(Master_madelantopesos_sin_drif) over ventana_6 as Master_madelantopesos_sin_drif_avg
#     , avg(Master_madelantodolares_sin_drif) over ventana_6 as Master_madelantodolares_sin_drif_avg
#     , avg(Master_fultimo_cierre) over ventana_6 as Master_fultimo_cierre_avg
#     , avg(Master_mpagado_sin_drif) over ventana_6 as Master_mpagado_sin_drif_avg
#     , avg(Master_mpagospesos_sin_drif) over ventana_6 as Master_mpagospesos_sin_drif_avg
#     , avg(Master_mpagosdolares_sin_drif) over ventana_6 as Master_mpagosdolares_sin_drif_avg
#     , avg(Master_fechaalta) over ventana_6 as Master_fechaalta_avg
#     , avg(Master_mconsumototal_sin_drif) over ventana_6 as Master_mconsumototal_sin_drif_avg
#     , avg(Master_cconsumos_sin_drif) over ventana_6 as Master_cconsumos_sin_drif_avg
#     , avg(Master_cadelantosefectivo) over ventana_6 as Master_cadelantosefectivo_avg
#     , avg(Master_mpagominimo_sin_drif) over ventana_6 as Master_mpagominimo_sin_drif_avg
#     , avg(Visa_delinquency) over ventana_6 as Visa_delinquency_avg
#     , avg(Visa_status) over ventana_6 as Visa_status_avg
#     , avg(Visa_mfinanciacion_limite_sin_drif) over ventana_6 as Visa_mfinanciacion_limite_sin_drif_avg
#     , avg(Visa_Fvencimiento) over ventana_6 as Visa_Fvencimiento_avg
#     , avg(Visa_Finiciomora) over ventana_6 as Visa_Finiciomora_avg
#     , avg(Visa_msaldototal_sin_drif) over ventana_6 as Visa_msaldototal_sin_drif_avg
#     , avg(Visa_msaldopesos_sin_drif) over ventana_6 as Visa_msaldopesos_sin_drif_avg
#     , avg(Visa_msaldodolares_sin_drif) over ventana_6 as Visa_msaldodolares_sin_drif_avg
#     , avg(Visa_mconsumospesos_sin_drif) over ventana_6 as Visa_mconsumospesos_sin_drif_avg
#     , avg(Visa_mconsumosdolares_sin_drif) over ventana_6 as Visa_mconsumosdolares_sin_drif_avg
#     , avg(Visa_mlimitecompra_sin_drif) over ventana_6 as Visa_mlimitecompra_sin_drif_avg
#     , avg(Visa_madelantopesos_sin_drif) over ventana_6 as Visa_madelantopesos_sin_drif_avg
#     , avg(Visa_madelantodolares_sin_drif) over ventana_6 as Visa_madelantodolares_sin_drif_avg
#     , avg(Visa_fultimo_cierre) over ventana_6 as Visa_fultimo_cierre_avg
#     , avg(Visa_mpagado_sin_drif) over ventana_6 as Visa_mpagado_sin_drif_avg
#     , avg(Visa_mpagospesos_sin_drif) over ventana_6 as Visa_mpagospesos_sin_drif_avg
#     , avg(Visa_mpagosdolares_sin_drif) over ventana_6 as Visa_mpagosdolares_sin_drif_avg
#     , avg(Visa_fechaalta) over ventana_6 as Visa_fechaalta_avg
#     , avg(Visa_mconsumototal_sin_drif) over ventana_6 as Visa_mconsumototal_sin_drif_avg
#     , avg(Visa_cconsumos) over ventana_6 as Visa_cconsumos_avg
#     , avg(Visa_cadelantosefectivo) over ventana_6 as Visa_cadelantosefectivo_avg
#     , avg(Visa_mpagominimo_sin_drif) over ventana_6 as Visa_mpagominimo_sin_drif_avg
#
#
# FROM table_2
# window ventana_6 as (partition by numero_de_cliente order by foto_mes rows between 6 preceding and current row)

# %%
# %%sql
# DROP TABLE IF EXISTS table_2

# %%
# %%sql
# ALTER TABLE table_3 DROP COLUMN tc_mconsumo_total;
# ALTER TABLE table_3 DROP COLUMN tc_limcompra_total;
# ALTER TABLE table_3 DROP COLUMN tc_pagado_total;
# ALTER TABLE table_3 DROP COLUMN pasivos_total;
# ALTER TABLE table_3 DROP COLUMN activos_total;
# ALTER TABLE table_3 DROP COLUMN flujos_ingresos_total;
# ALTER TABLE table_3 DROP COLUMN comisiones_total;
# ALTER TABLE table_3 DROP COLUMN gastos_total;
#
# ALTER TABLE table_3 DROP COLUMN mrentabilidad;
#  ALTER TABLE table_3 DROP COLUMN mrentabilidad_annual;
#  ALTER TABLE table_3 DROP COLUMN mcomisiones;
#  ALTER TABLE table_3 DROP COLUMN mactivos_margen;
#  ALTER TABLE table_3 DROP COLUMN mpasivos_margen;
#  ALTER TABLE table_3 DROP COLUMN mcuenta_corriente_adicional;
#  ALTER TABLE table_3 DROP COLUMN mcuenta_corriente;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro_adicional;
#  ALTER TABLE table_3 DROP COLUMN mcaja_ahorro_dolares;
#  ALTER TABLE table_3 DROP COLUMN mcuentas_saldo;
#  ALTER TABLE table_3 DROP COLUMN mautoservicio;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_visa_consumo;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_master_consumo;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_personales;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_prendarios;
#  ALTER TABLE table_3 DROP COLUMN mprestamos_hipotecarios;
#  ALTER TABLE table_3 DROP COLUMN mplazo_fijo_dolares;
#  ALTER TABLE table_3 DROP COLUMN mplazo_fijo_pesos;
#  ALTER TABLE table_3 DROP COLUMN minversion1_pesos;
#  ALTER TABLE table_3 DROP COLUMN minversion1_dolares;
#  ALTER TABLE table_3 DROP COLUMN minversion2;
#  ALTER TABLE table_3 DROP COLUMN mpayroll;
#  ALTER TABLE table_3 DROP COLUMN mpayroll2;
#  ALTER TABLE table_3 DROP COLUMN mcuenta_debitos_automaticos;
#  ALTER TABLE table_3 DROP COLUMN mttarjeta_visa_debitos_automaticos;
#  ALTER TABLE table_3 DROP COLUMN mttarjeta_master_debitos_automaticos;
#  ALTER TABLE table_3 DROP COLUMN mpagodeservicios;
#  ALTER TABLE table_3 DROP COLUMN mpagomiscuentas;
#  ALTER TABLE table_3 DROP COLUMN mcajeros_propios_descuentos;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_visa_descuentos;
#  ALTER TABLE table_3 DROP COLUMN mtarjeta_master_descuentos;
#  ALTER TABLE table_3 DROP COLUMN mcomisiones_mantenimiento;
#  ALTER TABLE table_3 DROP COLUMN mcomisiones_otras;
#  ALTER TABLE table_3 DROP COLUMN mforex_buy;
#  ALTER TABLE table_3 DROP COLUMN mforex_sell;
#  ALTER TABLE table_3 DROP COLUMN mtransferencias_recibidas;
#  ALTER TABLE table_3 DROP COLUMN mtransferencias_emitidas;
#  ALTER TABLE table_3 DROP COLUMN mextraccion_autoservicio;
#  ALTER TABLE table_3 DROP COLUMN mcheques_depositados;
#  ALTER TABLE table_3 DROP COLUMN mcheques_emitidos;
#  ALTER TABLE table_3 DROP COLUMN mcheques_depositados_rechazados;
#  ALTER TABLE table_3 DROP COLUMN mcheques_emitidos_rechazados;
#  ALTER TABLE table_3 DROP COLUMN matm;
#  ALTER TABLE table_3 DROP COLUMN matm_other;
#  ALTER TABLE table_3 DROP COLUMN Master_mfinanciacion_limite;
#  ALTER TABLE table_3 DROP COLUMN Master_msaldototal;
#  ALTER TABLE table_3 DROP COLUMN Master_msaldopesos;
#  ALTER TABLE table_3 DROP COLUMN Master_msaldodolares;
#  ALTER TABLE table_3 DROP COLUMN Master_mconsumospesos;
#  ALTER TABLE table_3 DROP COLUMN Master_mconsumosdolares;
#  ALTER TABLE table_3 DROP COLUMN Master_mlimitecompra;
#  ALTER TABLE table_3 DROP COLUMN Master_madelantopesos;
#  ALTER TABLE table_3 DROP COLUMN Master_madelantodolares;
#  ALTER TABLE table_3 DROP COLUMN Master_mpagado;
#  ALTER TABLE table_3 DROP COLUMN Master_mpagospesos;
#  ALTER TABLE table_3 DROP COLUMN Master_mpagosdolares;
#  ALTER TABLE table_3 DROP COLUMN Master_mconsumototal;
#  ALTER TABLE table_3 DROP COLUMN Master_mpagominimo;
#  ALTER TABLE table_3 DROP COLUMN Visa_mfinanciacion_limite;
#  ALTER TABLE table_3 DROP COLUMN Visa_msaldototal;
#  ALTER TABLE table_3 DROP COLUMN Visa_msaldopesos;
#  ALTER TABLE table_3 DROP COLUMN Visa_msaldodolares;
#  ALTER TABLE table_3 DROP COLUMN Visa_mconsumospesos;
#  ALTER TABLE table_3 DROP COLUMN Visa_mconsumosdolares;
#  ALTER TABLE table_3 DROP COLUMN Visa_mlimitecompra;
#  ALTER TABLE table_3 DROP COLUMN Visa_madelantopesos;
#  ALTER TABLE table_3 DROP COLUMN Visa_madelantodolares;
#  ALTER TABLE table_3 DROP COLUMN Visa_mpagado;
#  ALTER TABLE table_3 DROP COLUMN Visa_mpagospesos;
#  ALTER TABLE table_3 DROP COLUMN Visa_mpagosdolares;
#  ALTER TABLE table_3 DROP COLUMN Visa_mconsumototal;
#  ALTER TABLE table_3 DROP COLUMN Visa_mpagominimo;
# Out:
# UsageError: Cell magic `%%sql` not found.

# %%
# %%sql
# copy table_3 to '~/buckets/b1/datasets/competencia_03_ntile.csv.gz' (FORMAT CSV, HEADER)
